# %%
pip install cobra
# Out:
# Requirement already satisfied: cobra in c:\users\amitk\appdata\roaming\python\python38\site-packages (0.20.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: rich~=6.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (6.2.0)
# Requirement already satisfied: diskcache~=5.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (5.1.0)
# Requirement already satisfied: optlang<1.4.6 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cobra) (1.4.2)
# Requirement already satisfied: python-libsbml-experimental==5.18.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (5.18.3)

# %%
# !pip install gurobipy
import gurobipy as gp
# Out:
# Requirement already satisfied: pydantic~=1.6 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (1.7.2)
# Requirement already satisfied: pandas~=1.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cobra) (1.3.0)
# Requirement already satisfied: swiglpk in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (4.65.1)
# Requirement already satisfied: ruamel.yaml~=0.16 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (0.16.12)
# Requirement already satisfied: importlib-resources in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (3.3.0)
# Requirement already satisfied: future in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (0.18.2)
# Requirement already satisfied: httpx~=0.14 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (0.16.1)
# Requirement already satisfied: six in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (1.15.0)
# Requirement already satisfied: numpy~=1.13 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (1.19.4)
# Requirement already satisfied: depinfo in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (1.6.0)
# Requirement already satisfied: appdirs~=1.4 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra) (1.4.4)
# Requirement already satisfied: certifi in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra) (2020.11.8)
# Requirement already satisfied: httpcore==0.12.* in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra) (0.12.1)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra) (1.4.0)
# Requirement already satisfied: sniffio in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra) (1.2.0)
# Requirement already satisfied: h11==0.* in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpcore==0.12.*->httpx~=0.14->cobra) (0.11.0)
# Requirement already satisfied: sympy>=1.0.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from optlang<1.4.6->cobra) (1.6.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from pandas~=1.0->cobra) (2020.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from pandas~=1.0->cobra) (2.8.1)
# Requirement already satisfied: idna in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.14->cobra) (2.10)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra) (3.7.4.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra) (2.7.2)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra) (0.4.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra) (0.9.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from ruamel.yaml~=0.16->cobra) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from sympy>=1.0.0->optlang<1.4.6->cobra) (1.1.0)
# Requirement already satisfied: gurobipy in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (9.1.2)

# %% [markdown]
# ### Import packages

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import pickle
import cobra

print('Python version:', sys.version)
print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Matplotlib version:', matplotlib. __version__)
print('Pickle version:', pickle.format_version)
print('Cobrapy version:', cobra.__version__)
# Out:
# Python version: 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# Numpy version: 1.19.4
# Pandas version: 1.3.0
# Matplotlib version: 3.3.3
# Pickle version: 4.0
# Cobrapy version: 0.20.0

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# ### Create genome-scale model

# %%
from cobra.io import load_json_model, save_json_model, read_sbml_model, write_sbml_model
from cobra import Model, Reaction, Metabolite
from pandas import Series, DataFrame

model = load_json_model('iJN678.json')

# %%
#TCA cycle shunt reactions (Zhang and Bryant, 2011)

r_OXGDC = Reaction('OXGDC')
r_OXGDC.name = '2-oxoglutarate decarboxylase'
r_OXGDC.subsystem = 'Citrate cycle (TCA cycle)'
r_OXGDC.gene_reaction_rule = 'sll1981'
r_OXGDC.lower_bound = 0
r_OXGDC.upper_bound = 1000

r_OXGDC.add_metabolites({
                            model.metabolites.get_by_id("akg_c"): -1,
                            model.metabolites.get_by_id("h_c"): -1,
                            model.metabolites.get_by_id("co2_c"): 1,
                            model.metabolites.get_by_id("sucsal_c"): 1,
                           })

model.add_reactions([r_OXGDC])

#Light-independent serine biosynthesis pathway (Klemke et al., 2015)

r_PSTA = Reaction('PSTA')
r_PSTA.name = 'Phosphoserine transaminase'
r_PSTA.subsystem = 'Glycine and serine metabolism'
r_PSTA.gene_reaction_rule = 'sll1559'
r_PSTA.lower_bound = 0
r_PSTA.upper_bound = 1000

m_pser__L_c = Metabolite(id='pser__L_c', name='O-Phospho-L-serine', compartment='c', formula='C3H6NO6P')

r_PSTA.add_metabolites({model.metabolites.get_by_id("3php_c"): -1,
                        model.metabolites.get_by_id("glu__L_c"): -1,
                        model.metabolites.get_by_id("akg_c"): 1,
                        m_pser__L_c: 1, #
                        })

model.add_reactions([r_PSTA])

r_PSP = Reaction('PSP')
r_PSP.name = 'Phosphoserine phosphatase'
r_PSP.subsystem = 'Glycine and serine metabolism'
r_PSP.gene_reaction_rule = 'slr1124'
r_PSP.lower_bound = 0
r_PSP.upper_bound = 1000

r_PSP.add_metabolites({
                            model.metabolites.get_by_id("pser__L_c"): -1,
                            model.metabolites.get_by_id("h2o_c"): -1,
                            model.metabolites.get_by_id("h_c"): 2,
                            model.metabolites.get_by_id("pi_c"): 1,
                            model.metabolites.get_by_id("ser__L_c"): 1,
                            })

model.add_reactions([r_PSP])

#Phosphoketolase pathways (Xiong et al., 2015), (Bachhar et al., 2020)

r_PKETF = Reaction('PKETF')
r_PKETF.name = 'Phosphoketolase (fructose-6-phosphate utilizing)'
r_PKETF.subsystem = 'Pentose phosphate pathway'
r_PKETF.gene_reaction_rule = 'slr0453'
r_PKETF.lower_bound = 0
r_PKETF.upper_bound = 1000

r_PKETF.add_metabolites({model.metabolites.get_by_id("f6p_c"): -1,
                       model.metabolites.get_by_id("pi_c"): -1,
                       model.metabolites.get_by_id("h2o_c"): 1,
                       model.metabolites.get_by_id("actp_c"): 1,
                       model.metabolites.get_by_id("e4p_c"): 1,
                       })

model.add_reactions([r_PKETF])

r_PKETX = Reaction('PKETX')
r_PKETX.name = 'Phosphoketolase (xylulose-5-phosphate utilizing)'
r_PKETX.subsystem = 'Pentose phosphate pathway'
r_PKETX.gene_reaction_rule = 'slr0453'
r_PKETX.lower_bound = 0
r_PKETX.upper_bound = 1000

r_PKETX.add_metabolites({model.metabolites.get_by_id("xu5p__D_c"): -1,
                       model.metabolites.get_by_id("pi_c"): -1,
                       model.metabolites.get_by_id("h2o_c"): 1,
                       model.metabolites.get_by_id("actp_c"): 1,
                       model.metabolites.get_by_id("g3p_c"): 1,
                       })

model.add_reactions([r_PKETX])

#Entner–Doudoroff pathway (Chen et al., 2016)

r_GDH = Reaction('GDH')
r_GDH.name = 'Glucose dehydrogenase'
r_GDH.subsystem = 'Pentose phosphate pathway'
r_GDH.gene_reaction_rule = 'sll1709'
r_GDH.lower_bound = 0
r_GDH.upper_bound = 1000

m_glcn_c = Metabolite(id='glcn_c', name='D-Gluconate', compartment='c', formula='C6H11O7') #, charge='-1'

r_GDH.add_metabolites({model.metabolites.get_by_id("glc__bD_c"): -1,
                       model.metabolites.get_by_id("nadp_c"): -1,
                       model.metabolites.get_by_id("h2o_c"): -1,
                       model.metabolites.get_by_id("nadph_c"): 1,
                       model.metabolites.get_by_id("h_c"): 2,
                       m_glcn_c: 1, #
                       })

model.add_reactions([r_GDH])

r_GNK = Reaction('GNK')
r_GNK.name = 'Gluconokinase'
r_GNK.subsystem = 'Pentose phosphate pathway'
r_GNK.gene_reaction_rule = 'sll0593'
r_GNK.lower_bound = 0
r_GNK.upper_bound = 1000

r_GNK.add_metabolites({model.metabolites.get_by_id("atp_c"): -1,
                       model.metabolites.get_by_id("glcn_c"): -1,
                       model.metabolites.get_by_id("6pgc_c"): 1,
                       model.metabolites.get_by_id("adp_c"): 1,
                       model.metabolites.get_by_id("h_c"): 1,
                       })

model.add_reactions([r_GNK])

r_EDD = Reaction('EDD')
r_EDD.name = '6-phosphogluconate dehydratase'
r_EDD.subsystem = 'Pentose phosphate pathway'
r_EDD.gene_reaction_rule = 'slr0452'
r_EDD.lower_bound = 0
r_EDD.upper_bound = 1000

m_2ddg6p_c = Metabolite(id='2ddg6p_c', name='2-Dehydro-3-deoxy-D-gluconate 6-phosphate', compartment='c', formula='C6H8O9P') #, charge='-3'

r_EDD.add_metabolites({model.metabolites.get_by_id("6pgc_c"): -1,
                       model.metabolites.get_by_id("h2o_c"): 1,
                       m_2ddg6p_c: 1,
                       })

model.add_reactions([r_EDD])

r_EDA = Reaction('EDA')
r_EDA.name = '2-dehydro-3-deoxy-phosphogluconate aldolase'
r_EDA.subsystem = 'Pentose phosphate pathway'
r_EDA.gene_reaction_rule = 'sll0107'
r_EDA.lower_bound = 0
r_EDA.upper_bound = 1000

r_EDA.add_metabolites({model.metabolites.get_by_id("2ddg6p_c"): -1,
                       model.metabolites.get_by_id("g3p_c"): 1,
                       model.metabolites.get_by_id("pyr_c"): 1,
                        })

model.add_reactions([r_EDA])

#Modification to tyrosine biosynthesis (Bonner et al., 2004)

r_PAT1 = Reaction('PAT1')
r_PAT1.name = 'Prephenate transaminase (aspartate donor)'
r_PAT1.subsystem = 'Phenylalanine tyrosine and tryptophan biosynthesis'
r_PAT1.gene_reaction_rule = ''
r_PAT1.lower_bound = 0
r_PAT1.upper_bound = 1000

m_Largn_c = Metabolite(id='Largn_c', name='L-Arogenate', compartment='c', formula='C10H13NO5')

r_PAT1.add_metabolites({model.metabolites.get_by_id("pphn_c"): -1,
                       model.metabolites.get_by_id("asp__L_c"): -1,
                       model.metabolites.get_by_id("h_c"): -1,
                       model.metabolites.get_by_id("oaa_c"): 1,
                       m_Largn_c: 1,
                        })

model.add_reactions([r_PAT1])

r_PAT2 = Reaction('PAT2')
r_PAT2.name = 'Prephenate transaminase (glutamate donor)'
r_PAT2.subsystem = 'Phenylalanine tyrosine and tryptophan biosynthesis'
r_PAT2.gene_reaction_rule = ''
r_PAT2.lower_bound = 0
r_PAT2.upper_bound = 1000

r_PAT2.add_metabolites({model.metabolites.get_by_id("pphn_c"): -1,
                       model.metabolites.get_by_id("glu__L_c"): -1,
                       model.metabolites.get_by_id("h_c"): -1,
                       model.metabolites.get_by_id("Largn_c"): 1,
                       model.metabolites.get_by_id("akg_c"): 1,
                        })

model.add_reactions([r_PAT2])

r_PHEA = Reaction('PHEA')
r_PHEA.name = 'Prephenate dehydratase'
r_PHEA.subsystem = 'Phenylalanine tyrosine and tryptophan biosynthesis'
r_PHEA.gene_reaction_rule = 'sll1662'
r_PHEA.lower_bound = 0
r_PHEA.upper_bound = 1000

r_PHEA.add_metabolites({model.metabolites.get_by_id("Largn_c"): -1,
                       model.metabolites.get_by_id("phe__L_c"): 1,
                       model.metabolites.get_by_id("h2o_c"): 1,
                       model.metabolites.get_by_id("co2_c"): 1,
                        })

model.add_reactions([r_PHEA])

r_PHEA = Reaction('TYRA')
r_PHEA.name = 'Arogenate dehydrogenase'
r_PHEA.subsystem = 'Phenylalanine tyrosine and tryptophan biosynthesis'
r_PHEA.gene_reaction_rule = 'slr2081'
r_PHEA.lower_bound = 0
r_PHEA.upper_bound = 1000

r_PHEA.add_metabolites({model.metabolites.get_by_id("Largn_c"): -1,
                       model.metabolites.get_by_id("nadp_c"): -1,
                       model.metabolites.get_by_id("tyr__L_c"): 1,
                       model.metabolites.get_by_id("h_c"): 1,
                       model.metabolites.get_by_id("nadph_c"): 1,
                       model.metabolites.get_by_id("co2_c"): 1,
                        })

model.add_reactions([r_PHEA])

#Modification to Glycine Cleavage System (Joshi et al., 2017)

model.reactions.GLYCL_2.bounds = (0, 0)
model.reactions.GLYCL.bounds = (0, 0)

r_GLYCLa = Reaction('GLYCLa')
r_GLYCLa.name = 'Glycine Cleavage System'
r_GLYCLa.subsystem = 'Photorespiration'
r_GLYCLa.gene_reaction_rule = '(sll0171 or slr0879 or slr0293)'
r_GLYCLa.lower_bound = -1000
r_GLYCLa.upper_bound = 1000

m_samprot_c = Metabolite(id='samprot_c', name='S-Aminomethyldihydrolipoylprotein', compartment='c', formula='C6H9N3O')
m_lprot_c = Metabolite(id='lprot_c', name='Lipoylprotein', compartment='c', formula='C6H9N3O')

r_GLYCLa.add_metabolites({model.metabolites.get_by_id("gly_c"): -1,
                       m_lprot_c: -1,
                       model.metabolites.get_by_id("co2_c"): 1,
                       m_samprot_c: 1,
                        })

model.add_reactions([r_GLYCLa])

r_GLYCLb = Reaction('GLYCLb')
r_GLYCLb.name = 'Glycine Cleavage System'
r_GLYCLb.subsystem = 'Photorespiration'
r_GLYCLb.gene_reaction_rule = '(sll0171 or slr0879 or slr0293)'
r_GLYCLb.lower_bound = -1000
r_GLYCLb.upper_bound = 1000

m_dhlprot_c = Metabolite(id='dhlprot_c', name='dihydrolipolprotein', compartment='c', formula='C6H9N3O')

r_GLYCLb.add_metabolites({model.metabolites.get_by_id("thf_c"): -1,
                       model.metabolites.get_by_id("samprot_c"): -1,
                       model.metabolites.get_by_id("mlthf_c"): 1,
                       model.metabolites.get_by_id("nh4_c"): 1,
                       m_dhlprot_c: 1,
                       })

model.add_reactions([r_GLYCLb])

r_GLYCLc = Reaction('GLYCLc')
r_GLYCLc.name = 'Glycine Cleavage System'
r_GLYCLc.subsystem = 'Photorespiration'
r_GLYCLc.gene_reaction_rule = '(sll0171 or slr0879 or slr0293)'
r_GLYCLc.lower_bound = -1000
r_GLYCLc.upper_bound = 1000

m_dhlprot_c = Metabolite(id='dhlprot_c', name='dihydrolipolprotein', compartment='c', formula='C6H9N3O')

r_GLYCLc.add_metabolites({model.metabolites.get_by_id("nad_c"): -1,
                       model.metabolites.get_by_id("dhlprot_c"): -1,
                       model.metabolites.get_by_id("h_c"): 1,
                       model.metabolites.get_by_id("nadh_c"): 1,
                       model.metabolites.get_by_id("lprot_c"): 1,
                        })

model.add_reactions([r_GLYCLc])

#Modification to electron-transport chain reactions (Lea-Smith et al., 2015).

model.reactions.NDH1_1p.bounds = (0, 0)
model.reactions.NDH1_2p.bounds = (0, 0)
model.reactions.CBFCpp.bounds = (0, 0)
model.reactions.CBFC2pp.bounds = (0, 0)
model.reactions.CYO1b2pp_syn.bounds = (0, 0)
model.reactions.CYO1bpp_syn.bounds = (0, 0)
model.reactions.CYO1b2_syn.bounds = (0, 0)

r_NDH2_2p = Reaction('NDH2_1p')
r_NDH2_2p.name = 'NADH dehydrogenase 2'
r_NDH2_2p.subsystem = 'Oxidative phosphorylation'
r_NDH2_2p.gene_reaction_rule = 'slr1743'
r_NDH2_2p.lower_bound = 0
r_NDH2_2p.upper_bound = 1000

r_NDH2_2p.add_metabolites({model.metabolites.get_by_id("h_c"): -1,
                       model.metabolites.get_by_id("nadh_c"): -1,
                       model.metabolites.get_by_id("pq_p"): -1,
                       model.metabolites.get_by_id("nad_c"): 1,
                       model.metabolites.get_by_id("pqh2_p"): 1,
                       })

model.add_reactions([r_NDH2_2p])

r_ARTO = Reaction('ARTO')
r_ARTO.name = 'Alternative respiratory terminal oxidase'
r_ARTO.subsystem = 'Photosynthesis'
r_ARTO.gene_reaction_rule = '(slr2082 or slr2083 or sll0813)'
r_ARTO.lower_bound = 0
r_ARTO.upper_bound = 1000

r_ARTO.add_metabolites({model.metabolites.get_by_id("h_c"): -2,
                       model.metabolites.get_by_id("pqh2_p"): -1,
                       model.metabolites.get_by_id("o2_p"): -0.5,
                       model.metabolites.get_by_id("pq_p"): 1,
                       model.metabolites.get_by_id("h2o_p"): 1,
                       })

model.add_reactions([r_ARTO])

r_Flv2_Flv4 = Reaction('Flv2_4')
r_Flv2_Flv4.name = 'Flavodiiron 2/4'
r_Flv2_Flv4.subsystem = 'Photosynthesis'
r_Flv2_Flv4.gene_reaction_rule = '(sll0219 or sll0217)'
r_Flv2_Flv4.lower_bound = 0
r_Flv2_Flv4.upper_bound = 1000

r_Flv2_Flv4.add_metabolites({model.metabolites.get_by_id("h_c"): -2,
                                    model.metabolites.get_by_id("pqh2_u"): -1,
                                    model.metabolites.get_by_id("o2_u"): -0.5,
                                    model.metabolites.get_by_id("pq_u"): 1,
                                    model.metabolites.get_by_id("h2o_u"): 1,
                                    })

model.add_reactions([r_Flv2_Flv4])

#Modification to transhydrogenase PntAB (Kämäräinen, et al., 2016).

#model.reactions.NADTRHD.bounds = (-1000, 10000)

#Modification to Leucine transaminas (Joshi et al., 2017).
model.reactions.LEUTAi.bounds = (0, 0)

#ATP maintenance requirement

r_NGAM = Reaction('ATPM')
r_NGAM.name = 'ATP maintenance requirement'
r_NGAM.subsystem = 'Biomass and maintenance functions'
r_NGAM.gene_reaction_rule = ''
r_NGAM.lower_bound = 0
r_NGAM.upper_bound = 1000

r_NGAM.add_metabolites({model.metabolites.get_by_id("atp_c"): -1,
                                    model.metabolites.get_by_id("h2o_c"): -1,
                                    model.metabolites.get_by_id("adp_c"): 1,
                                    model.metabolites.get_by_id("h_c"): 1,
                                    model.metabolites.get_by_id("pi_c"): 1,
                        })

model.add_reactions([r_NGAM])

# %%
#save new GSM
#
#cobra.io.write_sbml_model(model,'iJN678_AK.xml')
#cobra.io.save_json_model(model, "iJN678_AK.json")

# %% [markdown]
# ### MEMOTE analysis

# %%
pip install memote
# Out:
# Requirement already satisfied: memote in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (0.12.0)
# Requirement already satisfied: click in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (8.1.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: travis-encrypt<1.2.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (1.1.2)
# Requirement already satisfied: cookiecutter in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (1.7.2)
# Requirement already satisfied: pytest>=4.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (4.6.11)
# Requirement already satisfied: click-configfile in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (0.2.3)

# %%
#import memote
#!memote report snapshot '/iJN678_2023.xml' --filename '/iJN678_2023.html'
# Out:
# Requirement already satisfied: sympy in c:\users\amitk\appdata\roaming\python\python38\site-packages (from memote) (1.6.2)
# Requirement already satisfied: pylru in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (1.2.0)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (4.6.2)
# Requirement already satisfied: cobra>=0.15.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from memote) (0.20.0)

# %% [markdown]
# ### Set model constraints

# %%
#set model objective to mixotrophic growth
model.objective = 'BIOMASS_Ec_SynMixo'
#set mixotropic growth by constraining glucose exchange reatcion.
model.reactions.EX_glc__D_e.bounds = (-0.38, 1000)
#set mixotropic growth by constraining HCO3 exchange reatcion.
model.reactions.EX_co2_e.bounds = (0, 1000)
model.reactions.EX_hco3_e.bounds = (0, 1000)
#set photon flux to lab scale conditions.
model.reactions.EX_photon_e.bounds = (-45, -45)
#blocking transhydrogenase PntAB
model.reactions.NADTRHD.bounds = (0, 0)
# Out:
# Requirement already satisfied: depinfo in c:\users\amitk\appdata\roaming\python\python38\site-packages (from memote) (1.6.0)
# Requirement already satisfied: numpydoc in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (1.1.0)
# Requirement already satisfied: goodtables~=2.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (2.5.2)

# %%
from cobra.flux_analysis.loopless import add_loopless

add_loopless(model)
# Out:
# Requirement already satisfied: future in c:\users\amitk\appdata\roaming\python\python38\site-packages (from memote) (0.18.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (1.3.0)
# Requirement already satisfied: six in c:\users\amitk\appdata\roaming\python\python38\site-packages (from memote) (1.15.0)
# Requirement already satisfied: gitpython in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (3.1.11)
# Requirement already satisfied: Jinja2 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (2.11.2)
# Requirement already satisfied: ruamel.yaml>=0.15 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from memote) (0.16.12)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (2.28.2)
# Requirement already satisfied: click-log in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (0.3.2)
# Requirement already satisfied: importlib-resources in c:\users\amitk\appdata\roaming\python\python38\site-packages (from memote) (3.3.0)
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from memote) (1.3.22)
# Requirement already satisfied: swiglpk in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (4.65.1)
# Requirement already satisfied: diskcache~=5.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (5.1.0)
# Requirement already satisfied: optlang<1.4.6 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cobra>=0.15.3->memote) (1.4.2)
# Requirement already satisfied: httpx~=0.14 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (0.16.1)
# Requirement already satisfied: numpy~=1.13 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (1.19.4)
# Requirement already satisfied: python-libsbml-experimental==5.18.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (5.18.3)
# Requirement already satisfied: pydantic~=1.6 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (1.7.2)
# Requirement already satisfied: appdirs~=1.4 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (1.4.4)
# Requirement already satisfied: rich~=6.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.15.3->memote) (6.2.0)
# Requirement already satisfied: statistics>=1.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from goodtables~=2.0->memote) (1.0.3.5)
# Requirement already satisfied: tableschema>=1.16.4 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from goodtables~=2.0->memote) (1.20.0)
# Requirement already satisfied: simpleeval>=0.9 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from goodtables~=2.0->memote) (0.9.10)
# Requirement already satisfied: click-default-group in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from goodtables~=2.0->memote) (1.2.2)
# Requirement already satisfied: datapackage>=1.10 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from goodtables~=2.0->memote) (1.15.1)
# Requirement already satisfied: tabulator>=1.40 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from goodtables~=2.0->memote) (1.53.1)
# Requirement already satisfied: colorama in c:\users\amitk\appdata\roaming\python\python38\site-packages (from click->memote) (0.4.4)
# Requirement already satisfied: jsonpointer>=1.10 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from datapackage>=1.10->goodtables~=2.0->memote) (2.0)
# Requirement already satisfied: jsonschema>=2.5 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from datapackage>=1.10->goodtables~=2.0->memote) (3.2.0)
# Requirement already satisfied: chardet>=3.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from datapackage>=1.10->goodtables~=2.0->memote) (4.0.0)
# Requirement already satisfied: unicodecsv>=0.14 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from datapackage>=1.10->goodtables~=2.0->memote) (0.14.1)
# Requirement already satisfied: certifi in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.15.3->memote) (2020.11.8)
# Requirement already satisfied: sniffio in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.15.3->memote) (1.2.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.15.3->memote) (1.4.0)
# Requirement already satisfied: httpcore==0.12.* in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.15.3->memote) (0.12.1)
# Requirement already satisfied: h11==0.* in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpcore==0.12.*->httpx~=0.14->cobra>=0.15.3->memote) (0.11.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jsonschema>=2.5->datapackage>=1.10->goodtables~=2.0->memote) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jsonschema>=2.5->datapackage>=1.10->goodtables~=2.0->memote) (20.3.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jsonschema>=2.5->datapackage>=1.10->goodtables~=2.0->memote) (51.0.0.post20201207)
# Requirement already satisfied: pytz>=2017.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from pandas->memote) (2020.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from pandas->memote) (2.8.1)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest>=4.0->memote) (8.6.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest>=4.0->memote) (21.3)
# Requirement already satisfied: py>=1.5.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest>=4.0->memote) (1.10.0)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest>=4.0->memote) (0.2.5)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest>=4.0->memote) (0.13.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest>=4.0->memote) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from requests->memote) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from requests->memote) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from requests->memote) (2.10)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra>=0.15.3->memote) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra>=0.15.3->memote) (2.7.2)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra>=0.15.3->memote) (3.7.4.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from ruamel.yaml>=0.15->memote) (0.2.2)
# Requirement already satisfied: docutils>=0.3 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from statistics>=1.0->goodtables~=2.0->memote) (0.16)
# Requirement already satisfied: mpmath>=0.19 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from sympy->memote) (1.1.0)
# Requirement already satisfied: cached-property>=1.5 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tableschema>=1.16.4->goodtables~=2.0->memote) (1.5.2)
# Requirement already satisfied: isodate>=0.5.4 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tableschema>=1.16.4->goodtables~=2.0->memote) (0.6.0)
# Requirement already satisfied: xlrd>=1.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tabulator>=1.40->goodtables~=2.0->memote) (2.0.1)
# Requirement already satisfied: ijson>=3.0.3 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tabulator>=1.40->goodtables~=2.0->memote) (3.1.3)
# Requirement already satisfied: openpyxl>=2.6 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tabulator>=1.40->goodtables~=2.0->memote) (3.0.5)
# Requirement already satisfied: boto3>=1.9 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tabulator>=1.40->goodtables~=2.0->memote) (1.16.47)
# Requirement already satisfied: linear-tsv>=1.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tabulator>=1.40->goodtables~=2.0->memote) (1.1.0)
# Requirement already satisfied: jsonlines>=1.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from tabulator>=1.40->goodtables~=2.0->memote) (1.2.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from boto3>=1.9->tabulator>=1.40->goodtables~=2.0->memote) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from boto3>=1.9->tabulator>=1.40->goodtables~=2.0->memote) (0.10.0)
# Requirement already satisfied: botocore<1.20.0,>=1.19.47 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from boto3>=1.9->tabulator>=1.40->goodtables~=2.0->memote) (1.19.47)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from openpyxl>=2.6->tabulator>=1.40->goodtables~=2.0->memote) (1.0.1)
# Requirement already satisfied: jdcal in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from openpyxl>=2.6->tabulator>=1.40->goodtables~=2.0->memote) (1.4.1)
# Requirement already satisfied: cryptography>=2.3 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from travis-encrypt<1.2.0->memote) (37.0.4)
# Requirement already satisfied: PyYAML>=3.12 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from travis-encrypt<1.2.0->memote) (5.3.1)
# Requirement already satisfied: pyperclip==1.6.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from travis-encrypt<1.2.0->memote) (1.6.0)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cryptography>=2.3->travis-encrypt<1.2.0->memote) (1.14.4)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cffi>=1.12->cryptography>=2.3->travis-encrypt<1.2.0->memote) (2.20)
# Requirement already satisfied: configparser>=3.5.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from click-configfile->memote) (5.0.1)
# Requirement already satisfied: MarkupSafe<2.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cookiecutter->memote) (1.1.1)
# Requirement already satisfied: jinja2-time>=0.2.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cookiecutter->memote) (0.2.0)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cookiecutter->memote) (4.0.1)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cookiecutter->memote) (0.4.4)
# Requirement already satisfied: poyo>=0.5.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cookiecutter->memote) (0.5.0)
# Requirement already satisfied: arrow in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter->memote) (0.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from python-slugify>=4.0.0->cookiecutter->memote) (1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from gitpython->memote) (4.0.5)
# Requirement already satisfied: smmap<4,>=3.0.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->memote) (3.0.4)
# Requirement already satisfied: sphinx>=1.6.5 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from numpydoc->memote) (3.4.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (0.7.12)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (1.0.1)
# Requirement already satisfied: imagesize in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (1.2.0)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (1.1.4)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (1.0.3)
# Requirement already satisfied: babel>=1.3 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (2.9.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (1.0.3)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from sphinx>=1.6.5->numpydoc->memote) (1.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from packaging->pytest>=4.0->memote) (2.4.7)

# %% [markdown]
# ### Set growth

# %%
pfba_solution = cobra.flux_analysis.pfba(model)
uMAX = pfba_solution.fluxes["BIOMASS_Ec_SynMixo"]
uMAX
# Out:
# 0.05613625445755588

# %%
model.reactions.BIOMASS_Ec_SynMixo.lower_bound = 0.1 * uMAX
production = abs(pfba_solution.fluxes["BIOMASS_Ec_SynMixo"])
production
# Out:
# 0.05613625445755588

# %%
pip install escher
# Out:
# Requirement already satisfied: escher in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (1.7.3)
# Requirement already satisfied: jsonschema<4,>=3.0.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from escher) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: ipywidgets<8,>=7.4.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from escher) (7.6.2)
#
# Requirement already satisfied: pandas>=0.18 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from escher) (1.3.0)
# Requirement already satisfied: Jinja2<3,>=2.7.3 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from escher) (2.11.2)
# Requirement already satisfied: cobra>=0.5.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from escher) (0.20.0)
# Requirement already satisfied: pytest<5,>=4.0.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from escher) (4.6.11)
# Requirement already satisfied: diskcache~=5.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (5.1.0)
# Requirement already satisfied: httpx~=0.14 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (0.16.1)
# Requirement already satisfied: python-libsbml-experimental==5.18.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (5.18.3)
# Requirement already satisfied: future in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (0.18.2)
# Requirement already satisfied: swiglpk in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (4.65.1)
# Requirement already satisfied: optlang<1.4.6 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cobra>=0.5.0->escher) (1.4.2)

# %%
import escher
from escher import Builder

pfba_solution_escher = cobra.flux_analysis.pfba(model)

builder = Builder(
    map_json = '#AMP_SOG_SER_PSP_map_titles.json',
    model_json='iJN678_2023_biomass_mixo.json',
    reaction_data=abs(pfba_solution_escher.fluxes)
)

builder.save_html('AMP_SOG_SER_PSP_iJN678_2023_biomass_mixo.html')
# Out:
# Requirement already satisfied: numpy~=1.13 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (1.19.4)
# Requirement already satisfied: appdirs~=1.4 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (1.4.4)
# Requirement already satisfied: pydantic~=1.6 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (1.7.2)
# Requirement already satisfied: rich~=6.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (6.2.0)
# Requirement already satisfied: ruamel.yaml~=0.16 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (0.16.12)
# Requirement already satisfied: six in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (1.15.0)
# Requirement already satisfied: importlib-resources in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (3.3.0)
# Requirement already satisfied: depinfo in c:\users\amitk\appdata\roaming\python\python38\site-packages (from cobra>=0.5.0->escher) (1.6.0)
# Requirement already satisfied: httpcore==0.12.* in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.5.0->escher) (0.12.1)
# Requirement already satisfied: certifi in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.5.0->escher) (2020.11.8)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.5.0->escher) (1.4.0)
# Requirement already satisfied: sniffio in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpx~=0.14->cobra>=0.5.0->escher) (1.2.0)
# Requirement already satisfied: h11==0.* in c:\users\amitk\appdata\roaming\python\python38\site-packages (from httpcore==0.12.*->httpx~=0.14->cobra>=0.5.0->escher) (0.11.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipywidgets<8,>=7.4.0->escher) (5.0.8)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipywidgets<8,>=7.4.0->escher) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipywidgets<8,>=7.4.0->escher) (7.20.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipywidgets<8,>=7.4.0->escher) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipywidgets<8,>=7.4.0->escher) (5.4.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipywidgets<8,>=7.4.0->escher) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher) (6.1)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (51.0.0.post20201207)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (3.0.8)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.7.5)
# Requirement already satisfied: colorama in c:\users\amitk\appdata\roaming\python\python38\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.4.4)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (4.4.2)
# Requirement already satisfied: pygments in c:\users\amitk\appdata\roaming\python\python38\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (2.7.2)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from Jinja2<3,>=2.7.3->escher) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jsonschema<4,>=3.0.1->escher) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jsonschema<4,>=3.0.1->escher) (0.17.3)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher) (4.7.0)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher) (0.2.0)
# Requirement already satisfied: sympy>=1.0.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from optlang<1.4.6->cobra>=0.5.0->escher) (1.6.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from pandas>=0.18->escher) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from pandas>=0.18->escher) (2020.4)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.2.5)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest<5,>=4.0.1->escher) (0.13.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest<5,>=4.0.1->escher) (1.4.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest<5,>=4.0.1->escher) (21.3)
# Requirement already satisfied: py>=1.5.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest<5,>=4.0.1->escher) (1.10.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from pytest<5,>=4.0.1->escher) (8.6.0)
# Requirement already satisfied: idna in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.14->cobra>=0.5.0->escher) (2.10)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra>=0.5.0->escher) (3.7.4.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from rich~=6.0->cobra>=0.5.0->escher) (0.9.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from ruamel.yaml~=0.16->cobra>=0.5.0->escher) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\amitk\appdata\roaming\python\python38\site-packages (from sympy>=1.0.0->optlang<1.4.6->cobra>=0.5.0->escher) (1.1.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (6.1.6)
# Requirement already satisfied: Send2Trash in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.9.0)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (20.1.0)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.9.1)
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher) (300)
# Requirement already satisfied: pywinpty>=0.5 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (1.14.4)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (2.20)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.5.1)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.4.4)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.6.0)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (3.2.1)
# Requirement already satisfied: async-generator in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (1.10)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (1.4.3)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\envs\cobrapy_ms\lib\site-packages (from packaging->pytest<5,>=4.0.1->escher) (2.4.7)

# %%
data = {'Productivity ': [production]}
productivity = pd.DataFrame(data=data, index=['Biomass'])
productivity_round = productivity.round(2)
productivity_round
# Out:
#          Productivity
# Biomass           0.06

# %%
import pickle

with open('biomass_mixo_productivity.pickle', 'wb') as handle:
    pickle.dump(productivity_round, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Flux variability analysis

# %%
from cobra.flux_analysis.variability import flux_variability_analysis

fva = flux_variability_analysis(model, fraction_of_optimum = 0.95, reaction_list=model.reactions)

for rxn in model.reactions: 
    pfba_all = pfba_solution.fluxes.to_frame()

merge = pfba_all.join(fva)

with pd.ExcelWriter('pfba_fva_biomass_mixo_all.xlsx') as writer:
    merge.to_excel(writer, sheet_name='mixo_biomass')

# %%
merge
# Out:
#                 fluxes    minimum    maximum
# EX_ac_e       0.000000   0.000000   0.057001
# 34DHOXPEGOX   0.000000   0.000000   0.000000
# EX_photon_e -45.000000 -45.000000 -45.000000
# 34HPPOR       0.000029   0.000028   0.000029
# EX_ca2_e     -0.000253  -0.000253  -0.000241
# ...                ...        ...        ...
# GLYCLc        0.006080  -0.027526   1.835969
# NDH2_1p       0.000000   0.000000   9.145229
# ARTO          0.000000   0.000000   9.145222
# Flv2_4        0.000000   0.000000  18.290471
# NGAM          0.000000   0.000000  30.667291
#
# [883 rows x 3 columns]

# %%
#Pyruvate

df_pyr = model.metabolites.pyr_c.summary(fva=0.95).to_frame()
rxn_name_pyr = []
rxn_subsystem_pyr = []
rxn_string_pyr = []

rxn_pyr = df_pyr['reaction'].tolist()
for i in range(len(rxn_pyr)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_pyr[i]:
            name_pyr = model.reactions[j].name
            rxn_name_pyr.append(name_pyr)
            subsystem_pyr = model.reactions[j].subsystem
            rxn_subsystem_pyr.append(subsystem_pyr)
            string_pyr = model.reactions[j].build_reaction_string()
            rxn_string_pyr.append(string_pyr)
df_pyr.insert(0, 'desciption', rxn_name_pyr)
df_pyr.insert(1, 'subsystem', rxn_subsystem_pyr)
df_pyr.insert(7, 'string', rxn_string_pyr)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_pyr_produce = df_pyr.loc[((df_pyr["flux"] > 0) & ((df_pyr["factor"] > 0) | (df_pyr["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_pyr_consume = df_pyr.loc[((df_pyr["flux"] < 0) & ((df_pyr["factor"] < 0) | (df_pyr["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_pyr_produce = (df_pyr_produce['flux'] / 
                  df_pyr_produce['flux'].sum()) * 100
df_pyr_produce.insert(3, 'percent', percent_pyr_produce)

percent_pyr_consume = (df_pyr_consume['flux'] / 
                  df_pyr_consume['flux'].sum()) * 100
df_pyr_consume.insert(3, 'percent', percent_pyr_consume)

# %%
df_pyr_produce.sort_values(by='percent', ascending=False)
# Out:
#                                                 desciption  \
# EDA            2-dehydro-3-deoxy-phosphogluconate aldolase
# ME2                                    Malic enzyme (NADP)
# SERD_L                                  L-serine deaminase
# ANS                                  Anthranilate synthase
# SHCHCS2  2-succinyl-6-hydroxy-2,4-cyclohexadiene 1-carb...
# ADCL                              4-aminobenzoate synthase
#
#                                                  subsystem      flux  \
# EDA                              Pentose phosphate pathway  0.090168
# ME2                                    Pyruvate metabolism  0.047587
# SERD_L                     Arginine and proline metabolism  0.016614
# ANS      Phenylalanine tyrosine and tryptophan biosynth...  0.004002
# SHCHCS2      Ubiquinone and other pterpenoids biosynthesis  0.000092
# ADCL                                   Folate biosynthesis  0.000050
#
#            percent   minimum    maximum  \
# EDA      56.883459  0.000000  10.401168
# ME2      30.020821  0.000000  15.508843
# SERD_L   10.480939  0.000000  10.038472
# ANS       2.524933  0.003802   0.004002
# SHCHCS2   0.058235  0.000088   0.000092
# ADCL      0.031612  0.000048   0.000050
#
#                                                     string
# EDA                             2ddg6p_c --> g3p_c + pyr_c
# ME2          mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c
# SERD_L                          ser__L_c --> nh4_c + pyr_c
# ANS      chor_c + gln__L_c --> anth_c + glu__L_c + h_c ...
# SHCHCS2  ichor_c + ssaltpp_c --> 2shchc_c + pyr_c + thm...
# ADCL                     4adcho_c --> 4abz_c + h_c + pyr_c

# %%
df_pyr_consume.sort_values(by='percent', ascending=False)
# Out:
#                                      desciption  \
# ACLS                      Acetolactate synthase
# ALAD_L                  L-alanine dehydrogenase
# ACHBS       2-aceto-2-hydroxybutanoate synthase
# DHDPS              Dihydrodipicolinate synthase
# DXPS    1-deoxy-D-xylulose 5-phosphate synthase
#
#                                           subsystem      flux    percent  \
# ACLS            C5-Branched dibasic acid metabolism -0.093835  59.196850
# ALAD_L  Alanine, aspartate and glutamate metabolism -0.026184  16.518435
# ACHBS    Valine leucine and isoleucine biosynthesis -0.016217  10.230838
# DHDPS                             Lysine metabolism -0.012228   7.714227
# DXPS                            Sterol biosynthesis -0.010049   6.339651
#
#          minimum   maximum                                             string
# ACLS   -0.093835 -0.089143              h_c + 2.0 pyr_c --> alac__S_c + co2_c
# ALAD_L -3.292890  0.000000  ala__L_c + h2o_c + nad_c <-- h_c + nadh_c + nh...
# ACHBS  -0.016217 -0.015406         2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
# DHDPS  -0.012228 -0.011617     aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c
# DXPS   -0.010049 -0.009547           g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c

# %%
#ATP

df_atp = model.metabolites.atp_c.summary(fva=0.95).to_frame()
rxn_name_atp = []
rxn_subsystem_atp = []
rxn_string_atp = []

rxn_atp = df_atp['reaction'].tolist()
for i in range(len(rxn_atp)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_atp[i]:
            name_atp = model.reactions[j].name
            rxn_name_atp.append(name_atp)
            subsystem_atp = model.reactions[j].subsystem
            rxn_subsystem_atp.append(subsystem_atp)
            string_atp = model.reactions[j].build_reaction_string()
            rxn_string_atp.append(string_atp)
df_atp.insert(0, 'desciption', rxn_name_atp)
df_atp.insert(1, 'subsystem', rxn_subsystem_atp)
df_atp.insert(7, 'string', rxn_string_atp)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_atp_produce = df_atp.loc[((df_atp["flux"] > 0) & ((df_atp["factor"] > 0) | (df_atp["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_atp_consume = df_atp.loc[((df_atp["flux"] < 0) & ((df_atp["factor"] < 0) | (df_atp["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_atp_produce = (df_atp_produce['flux'] / 
                  df_atp_produce['flux'].sum()) * 100
df_atp_produce.insert(3, 'percent', percent_atp_produce)

percent_atp_consume = (df_atp_consume['flux'] / 
                  df_atp_consume['flux'].sum()) * 100
df_atp_consume.insert(3, 'percent', percent_atp_consume)

# %%
df_atp_produce.sort_values(by='percent', ascending=False)
# Out:
#                       desciption                  subsystem       flux  \
# ATPSu          ATP synthetase(u)  Oxidative phosphorylation  10.695235
# URIDK2r  Uridylate kinase (dUMP)      Pyrimidine metabolism   0.001482
# PPK2        Polyphosphate kinase  Oxidative phosphorylation   0.000013
#
#            percent    minimum    maximum  \
# ATPSu    99.986027  10.544896  34.061219
# URIDK2r   0.013856   0.001408   0.001482
# PPK2      0.000117   0.000012   0.000012
#
#                                                     string
# ATPSu    3.0 adp_c + 14.0 h_u + 3.0 pi_c --> 3.0 atp_c ...
# URIDK2r                  atp_c + dump_c <=> adp_c + dudp_c
# PPK2                      atp_c + ppi_c <=> adp_c + pppi_c

# %%
df_atp_consume.sort_values(by='percent', ascending=False)
# Out:
#                                                            desciption  \
# CYPHYS                                         Cyanophycin sinthetase
# BIOMASS_Ec_SynMixo                       Mixotrophic Biomass Ecuation
# GLNS                                             Glutamine synthetase
# NO3abcpp                 Nitrate transport via ABC system (periplasm)
# HEX1                                       Hexokinase (D-glucose:ATP)
# ...                                                               ...
# GTHS                                           Glutathione synthetase
# ADCPS2                          Adenosylcobinamide-phosphate synthase
# LTHRK                                              L threonine kinase
# CYRDAAT             Cob(I)yrinic acid a,c-diamide adenosyltransferase
# COCHL                                                Cobaltochelatase
#
#                                                subsystem      flux    percent  \
# CYPHYS                            Cyanophycin metabolism -6.078831  56.828872
# BIOMASS_Ec_SynMixo     Biomass and maintenance functions -2.162717  20.218484
# GLNS                                 Nitrogen metabolism -0.519294   4.854700
# NO3abcpp                                       Transport -0.506019   4.730594
# HEX1                          Glycolysis/Gluconeogenesis -0.380000   3.552488
# ...                                                  ...       ...        ...
# GTHS                                Glutamate metabolism -0.000013   0.000117
# ADCPS2              Porphyrin and chlorophyll metabolism -0.000013   0.000117
# LTHRK               Porphyrin and chlorophyll metabolism -0.000013   0.000117
# CYRDAAT             Porphyrin and chlorophyll metabolism -0.000013   0.000117
# COCHL               Porphyrin and chlorophyll metabolism -0.000013   0.000117
#
#                       minimum   maximum  \
# CYPHYS             -30.667402  0.000000
# BIOMASS_Ec_SynMixo  -2.162717 -2.054581
# GLNS               -30.859049 -0.072159
# NO3abcpp            -0.537718 -0.480718
# HEX1                -0.380000 -0.361000
# ...                       ...       ...
# GTHS                -0.000013 -0.000012
# ADCPS2              -0.000012 -0.000012
# LTHRK               -0.000013 -0.000012
# CYRDAAT             -0.000012 -0.000012
# COCHL               -0.000012 -0.000012
#
#                                                                string
# CYPHYS              arg__L_c + asp__L_c + 2.0 atp_c + precyanphy_c...
# BIOMASS_Ec_SynMixo  0.000223 10fthf_c + 0.000223 5mthf_c + 0.00027...
# GLNS                atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c ...
# NO3abcpp            atp_c + h2o_c + no3_p --> adp_c + h_c + no3_c ...
# HEX1                         atp_c + glc__D_c --> adp_c + g6p_c + h_c
# ...                                                               ...
# GTHS                atp_c + glucys_c + gly_c --> adp_c + gthrd_c +...
# ADCPS2              adcobhex_c + applp_c + atp_c --> adocbip_c + a...
# LTHRK                       atp_c + thr__L_c --> adp_c + h_c + thrp_c
# CYRDAAT                atp_c + co1dam_c + h_c --> adcobdam_c + pppi_c
# COCHL               atp_c + cobalt2_c + h2o_c + hgbam_c --> adp_c ...
#
# [80 rows x 7 columns]

# %%
#ADP

df_adp = model.metabolites.adp_c.summary(fva=0.95).to_frame()
rxn_name_adp = []
rxn_subsystem_adp = []
rxn_string_adp = []

rxn_adp = df_adp['reaction'].tolist()
for i in range(len(rxn_adp)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_adp[i]:
            name_adp = model.reactions[j].name
            rxn_name_adp.append(name_adp)
            subsystem_adp = model.reactions[j].subsystem
            rxn_subsystem_adp.append(subsystem_adp)
            string_adp = model.reactions[j].build_reaction_string()
            rxn_string_adp.append(string_adp)
df_adp.insert(0, 'desciption', rxn_name_adp)
df_adp.insert(1, 'subsystem', rxn_subsystem_adp)
df_adp.insert(7, 'string', rxn_string_adp)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_adp_produce = df_adp.loc[((df_adp["flux"] > 0) & ((df_adp["factor"] > 0) | (df_adp["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_adp_consume = df_adp.loc[((df_adp["flux"] < 0) & ((df_adp["factor"] < 0) | (df_adp["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_adp_produce = (df_adp_produce['flux'] / 
                  df_adp_produce['flux'].sum()) * 100
df_adp_produce.insert(3, 'percent', percent_adp_produce)

percent_adp_consume = (df_adp_consume['flux'] / 
                  df_adp_consume['flux'].sum()) * 100
df_adp_consume.insert(3, 'percent', percent_adp_consume)

# %%
df_adp_produce.sort_values(by='percent', ascending=False)
# Out:
#                                                       desciption  \
# CYPHYS                                    Cyanophycin sinthetase
# BIOMASS_Ec_SynMixo                  Mixotrophic Biomass Ecuation
# GLNS                                        Glutamine synthetase
# NO3abcpp            Nitrate transport via ABC system (periplasm)
# HEX1                                  Hexokinase (D-glucose:ATP)
# ...                                                          ...
# ADCPS2                     Adenosylcobinamide-phosphate synthase
# LTHRK                                         L threonine kinase
# GTHS                                      Glutathione synthetase
# GLUCYS                         Gamma-glutamylcysteine synthetase
# COCHL                                           Cobaltochelatase
#
#                                                subsystem      flux    percent  \
# CYPHYS                            Cyanophycin metabolism  6.078831  56.821026
# BIOMASS_Ec_SynMixo     Biomass and maintenance functions  2.155071  20.144225
# GLNS                                 Nitrogen metabolism  0.519294   4.854030
# NO3abcpp                                       Transport  0.506019   4.729941
# HEX1                          Glycolysis/Gluconeogenesis  0.380000   3.551997
# ...                                                  ...       ...        ...
# ADCPS2              Porphyrin and chlorophyll metabolism  0.000013   0.000117
# LTHRK               Porphyrin and chlorophyll metabolism  0.000013   0.000117
# GTHS                                Glutamate metabolism  0.000013   0.000117
# GLUCYS                              Glutamate metabolism  0.000013   0.000117
# COCHL               Porphyrin and chlorophyll metabolism  0.000013   0.000117
#
#                      minimum    maximum  \
# CYPHYS              0.000000  30.667402
# BIOMASS_Ec_SynMixo  2.047317   2.155071
# GLNS                0.072159  30.859049
# NO3abcpp            0.480718   0.537718
# HEX1                0.361000   0.380000
# ...                      ...        ...
# ADCPS2              0.000012   0.000013
# LTHRK               0.000012   0.000013
# GTHS                0.000012   0.000012
# GLUCYS              0.000012   0.000012
# COCHL               0.000012   0.000012
#
#                                                                string
# CYPHYS              arg__L_c + asp__L_c + 2.0 atp_c + precyanphy_c...
# BIOMASS_Ec_SynMixo  0.000223 10fthf_c + 0.000223 5mthf_c + 0.00027...
# GLNS                atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c ...
# NO3abcpp            atp_c + h2o_c + no3_p --> adp_c + h_c + no3_c ...
# HEX1                         atp_c + glc__D_c --> adp_c + g6p_c + h_c
# ...                                                               ...
# ADCPS2              adcobhex_c + applp_c + atp_c --> adocbip_c + a...
# LTHRK                       atp_c + thr__L_c --> adp_c + h_c + thrp_c
# GTHS                atp_c + glucys_c + gly_c --> adp_c + gthrd_c +...
# GLUCYS              atp_c + cys__L_c + glu__L_c --> adp_c + glucys...
# COCHL               atp_c + cobalt2_c + h2o_c + hgbam_c --> adp_c ...
#
# [64 rows x 7 columns]

# %%
df_adp_consume.sort_values(by='percent', ascending=False)
# Out:
#                                          desciption  \
# ATPSu                             ATP synthetase(u)
# URIDK2r                     Uridylate kinase (dUMP)
# RNDR1    Ribonucleoside-diphosphate reductase (ADP)
# PPK2                           Polyphosphate kinase
#
#                          subsystem       flux    percent    minimum  \
# ATPSu    Oxidative phosphorylation -10.695235  99.972223 -34.061219
# URIDK2r      Pyrimidine metabolism  -0.001482   0.013854  -0.001482
# RNDR1            Purine metabolism  -0.001477   0.013806  -0.001477
# PPK2     Oxidative phosphorylation  -0.000013   0.000117  -0.000012
#
#            maximum                                             string
# ATPSu   -10.544917  3.0 adp_c + 14.0 h_u + 3.0 pi_c --> 3.0 atp_c ...
# URIDK2r  -0.001408                  atp_c + dump_c <=> adp_c + dudp_c
# RNDR1    -0.001403       adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# PPK2     -0.000012                   atp_c + ppi_c <=> adp_c + pppi_c

# %%
#AMP

df_amp = model.metabolites.amp_c.summary(fva=0.95).to_frame()
rxn_name_amp = []
rxn_subsystem_amp = []
rxn_string_amp = []

rxn_amp = df_amp['reaction'].tolist()
for i in range(len(rxn_amp)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_amp[i]:
            name_amp = model.reactions[j].name
            rxn_name_amp.append(name_amp)
            subsystem_amp = model.reactions[j].subsystem
            rxn_subsystem_amp.append(subsystem_amp)
            string_amp = model.reactions[j].build_reaction_string()
            rxn_string_amp.append(string_amp)
df_amp.insert(0, 'desciption', rxn_name_amp)
df_amp.insert(1, 'subsystem', rxn_subsystem_amp)
df_amp.insert(7, 'string', rxn_string_amp)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_amp_produce = df_amp.loc[((df_amp["flux"] > 0) & ((df_amp["factor"] > 0) | (df_amp["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_amp_consume = df_amp.loc[((df_amp["flux"] < 0) & ((df_amp["factor"] < 0) | (df_amp["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_amp_produce = (df_amp_produce['flux'] / 
                  df_amp_produce['flux'].sum()) * 100
df_amp_produce.insert(3, 'percent', percent_amp_produce)

percent_amp_consume = (df_amp_consume['flux'] / 
                  df_amp_consume['flux'].sum()) * 100
df_amp_consume.insert(3, 'percent', percent_amp_consume)

# %%
df_amp_produce.sort_values(by='percent', ascending=False)
# Out:
#                                                desciption  \
# PRPPS              Phosphoribosylpyrophosphate synthetase
# ARGSS                          Argininosuccinate synthase
# ADSL1r                              Adenylsuccinate lyase
# ASNS1         Asparagine synthase (glutamine-hydrolysing)
# BPNT                      3',5'-bisphosphate nucleotidase
# GLUTRS                           Glutamyl-tRNA synthetase
# GMPS2                                        GMP synthase
# ADPT                    Adenine phosphoribosyltransferase
# NADS2       Nicotinate-mononucleotide adenylyltransferase
# SUCBZL                      O-succinylbenzoate-CoA ligase
# HPPK    2-amino-4-hydroxy-6-hydroxymethyldihydropterid...
# PANTS                               Pantothenate synthase
#
#                                             subsystem      flux    percent  \
# PRPPS                       Pentose phosphate pathway  0.046429  39.473797
# ARGSS     Alanine, aspartate and glutamate metabolism  0.015267  12.980071
# ADSL1r                              Purine metabolism  0.014129  12.012121
# ASNS1                             Nitrogen metabolism  0.010474   8.904925
# BPNT        Sulfur Cysteine and methionine metabolism  0.010438   8.874689
# GLUTRS                           Glutamate metabolism  0.009917   8.431789
# GMPS2                               Purine metabolism  0.008871   7.541899
# ADPT                                Purine metabolism  0.001792   1.523408
# NADS2                            Glutamate metabolism  0.000128   0.108724
# SUCBZL  Ubiquinone and other pterpenoids biosynthesis  0.000092   0.078482
# HPPK                              Folate biosynthesis  0.000050   0.042603
# PANTS               Pantothenate and CoA biosynthesis  0.000032   0.027492
#
#          minimum    maximum                                             string
# PRPPS   0.044107  15.377826             atp_c + r5p_c <=> amp_c + h_c + prpp_c
# ARGSS   0.014504  13.864298  asp__L_c + atp_c + citr__L_c --> amp_c + argsu...
# ADSL1r  0.013422   0.014129                          dcamp_c <=> amp_c + fum_c
# ASNS1   0.009950  10.232418  asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c ...
# BPNT    0.009916   0.010438                     h2o_c + pap_c --> amp_c + pi_c
# GLUTRS  0.009422   0.009917  atp_c + glu__L_c + trnaglu_c --> amp_c + glutr...
# GMPS2   0.000000   0.008871  atp_c + gln__L_c + h2o_c + xmp_c --> amp_c + g...
# ADPT    0.001702  15.335358                   ade_c + prpp_c --> amp_c + ppi_c
# NADS2   0.000121   0.000128  atp_c + dnad_c + gln__L_c + h2o_c --> amp_c + ...
# SUCBZL  0.000088   0.000092  atp_c + coa_c + sucbz_c --> amp_c + ppi_c + sb...
# HPPK    0.000048   0.000050        2ahhmp_c + atp_c --> 2ahhmd_c + amp_c + h_c
# PANTS   0.000031   0.000031  ala_B_c + atp_c + pant__R_c --> amp_c + h_c + ...

# %%
df_amp_consume.sort_values(by='percent', ascending=False)
# Out:
#             desciption          subsystem      flux  percent    minimum  \
# ADK1  Adenylate kinase  Purine metabolism -0.117619    100.0 -30.779083
#
#        maximum                       string
# ADK1 -0.111738  amp_c + atp_c <=> 2.0 adp_c

# %%
#Pi

df_pi = model.metabolites.pi_c.summary(fva=0.95).to_frame()
rxn_name_pi = []
rxn_subsystem_pi = []
rxn_string_pi = []

rxn_pi = df_pi['reaction'].tolist()
for i in range(len(rxn_pi)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_pi[i]:
            name_pi = model.reactions[j].name
            rxn_name_pi.append(name_pi)
            subsystem_pi = model.reactions[j].subsystem
            rxn_subsystem_pi.append(subsystem_pi)
            string_pi = model.reactions[j].build_reaction_string()
            rxn_string_pi.append(string_pi)
df_pi.insert(0, 'desciption', rxn_name_pi)
df_pi.insert(1, 'subsystem', rxn_subsystem_pi)
df_pi.insert(7, 'string', rxn_string_pi)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_pi_produce = df_pi.loc[((df_pi["flux"] > 0) & ((df_pi["factor"] > 0) | (df_pi["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_pi_consume = df_pi.loc[((df_pi["flux"] < 0) & ((df_pi["factor"] < 0) | (df_pi["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_pi_produce = (df_pi_produce['flux'] / 
                  df_pi_produce['flux'].sum()) * 100
df_pi_produce.insert(3, 'percent', percent_pi_produce)

percent_pi_consume = (df_pi_consume['flux'] / 
                  df_pi_consume['flux'].sum()) * 100
df_pi_consume.insert(3, 'percent', percent_pi_consume)

# %%
df_pi_produce.sort_values(by='percent', ascending=False)
# Out:
#                                                            desciption  \
# CYPHYS                                         Cyanophycin sinthetase
# BIOMASS_Ec_SynMixo                       Mixotrophic Biomass Ecuation
# GLNS                                             Glutamine synthetase
# NO3abcpp                 Nitrate transport via ABC system (periplasm)
# PPA                                           Inorganic diphosphatase
# ...                                                               ...
# ADCPS2                          Adenosylcobinamide-phosphate synthase
# GTHS                                           Glutathione synthetase
# GLUCYS                              Gamma-glutamylcysteine synthetase
# COCHL                                                Cobaltochelatase
# PGPP161             Phosphatidylglycerol phosphate phosphatase (n-...
#
#                                                subsystem      flux    percent  \
# CYPHYS                            Cyanophycin metabolism  6.078831  55.322426
# BIOMASS_Ec_SynMixo     Biomass and maintenance functions  2.154857  19.610999
# GLNS                                 Nitrogen metabolism  0.519294   4.726009
# NO3abcpp                                       Transport  0.506019   4.605193
# PPA                            Oxidative phosphorylation  0.361856   3.293195
# ...                                                  ...       ...        ...
# ADCPS2              Porphyrin and chlorophyll metabolism  0.000013   0.000114
# GTHS                                Glutamate metabolism  0.000013   0.000114
# GLUCYS                              Glutamate metabolism  0.000013   0.000114
# COCHL               Porphyrin and chlorophyll metabolism  0.000013   0.000114
# PGPP161                          Fatty acid biosynthesis  0.000008   0.000070
#
#                      minimum    maximum  \
# CYPHYS              0.000000  30.667402
# BIOMASS_Ec_SynMixo  2.047115   2.154857
# GLNS                0.072159  30.859049
# NO3abcpp            0.480718   0.537718
# PPA                 0.343764  61.678569
# ...                      ...        ...
# ADCPS2              0.000012   0.000012
# GTHS                0.000012   0.000012
# GLUCYS              0.000012   0.000012
# COCHL               0.000012   0.000012
# PGPP161             0.000007   0.000008
#
#                                                                string
# CYPHYS              arg__L_c + asp__L_c + 2.0 atp_c + precyanphy_c...
# BIOMASS_Ec_SynMixo  0.000223 10fthf_c + 0.000223 5mthf_c + 0.00027...
# GLNS                atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c ...
# NO3abcpp            atp_c + h2o_c + no3_p --> adp_c + h_c + no3_c ...
# PPA                                  h2o_c + ppi_c --> h_c + 2.0 pi_c
# ...                                                               ...
# ADCPS2              adcobhex_c + applp_c + atp_c --> adocbip_c + a...
# GTHS                atp_c + glucys_c + gly_c --> adp_c + gthrd_c +...
# GLUCYS              atp_c + cys__L_c + glu__L_c --> adp_c + glucys...
# COCHL               atp_c + cobalt2_c + h2o_c + hgbam_c --> adp_c ...
# PGPP161                           h2o_c + pgp161_c --> pg161_c + pi_c
#
# [77 rows x 7 columns]

# %%
df_pi_consume.sort_values(by='percent', ascending=False)
# Out:
#                                              desciption  \
# ATPSu                                 ATP synthetase(u)
# PKETX  Phosphoketolase (xylulose-5-phosphate utilizing)
# PKETF  Phosphoketolase (fructose-6-phosphate utilizing)
# PUNP1       Purine-nucleoside phosphorylase (Adenosine)
# MTAP               5  methylthioadenosine phosphorylase
#
#                                        subsystem       flux    percent  \
# ATPSu                  Oxidative phosphorylation -10.695235  97.335551
# PKETX                  Pentose phosphate pathway  -0.153724   1.399017
# PKETF                  Pentose phosphate pathway  -0.137254   1.249125
# PUNP1                      Pyrimidine metabolism  -0.001413   0.012861
# MTAP   Sulfur Cysteine and methionine metabolism  -0.000379   0.003446
#
#          minimum    maximum                                             string
# ATPSu -34.061219 -10.544917  3.0 adp_c + 14.0 h_u + 3.0 pi_c --> 3.0 atp_c ...
# PKETX  -4.668301   0.000000        pi_c + xu5p__D_c --> actp_c + g3p_c + h2o_c
# PKETF  -4.668314   0.000000            f6p_c + pi_c --> actp_c + e4p_c + h2o_c
# PUNP1 -15.335044  -0.001343                     adn_c + pi_c <=> ade_c + r1p_c
# MTAP   -0.000379  -0.000360                 5mta_c + pi_c --> 5mdr1p_c + ade_c

# %%
#NADPH

df_nadph = model.metabolites.nadph_c.summary(fva=0.95).to_frame()
rxn_name_nadph = []
rxn_subsystem_nadph = []
rxn_string_nadph = []

rxn_nadph = df_nadph['reaction'].tolist()
for i in range(len(rxn_nadph)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_nadph[i]:
            name_nadph = model.reactions[j].name
            rxn_name_nadph.append(name_nadph)
            subsystem_nadph = model.reactions[j].subsystem
            rxn_subsystem_nadph.append(subsystem_nadph)
            string_nadph = model.reactions[j].build_reaction_string()
            rxn_string_nadph.append(string_nadph)
df_nadph.insert(0, 'desciption', rxn_name_nadph)
df_nadph.insert(1, 'subsystem', rxn_subsystem_nadph)
df_nadph.insert(7, 'string', rxn_string_nadph)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_nadph_produce = df_nadph.loc[((df_nadph["flux"] > 0) & ((df_nadph["factor"] > 0) | (df_nadph["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_nadph_consume = df_nadph.loc[((df_nadph["flux"] < 0) & ((df_nadph["factor"] < 0) | (df_nadph["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_nadph_produce = (df_nadph_produce['flux'] / 
                  df_nadph_produce['flux'].sum()) * 100
df_nadph_produce.insert(3, 'percent', percent_nadph_produce)

percent_nadph_consume = (df_nadph_consume['flux'] / 
                  df_nadph_consume['flux'].sum()) * 100
df_nadph_consume.insert(3, 'percent', percent_nadph_consume)

# %%
df_nadph_produce.sort_values(by='percent', ascending=False)
# Out:
#                                                  desciption  \
# G6PDH2r                   Glucose 6-phosphate dehydrogenase
# GND                          Phosphogluconate dehydrogenase
# ICDHyr                      Isocitrate dehydrogenase (NADP)
# ME2                                     Malic enzyme (NADP)
# MTHFD        Methylenetetrahydrofolate dehydrogenase (NADP)
# FNOR                           Ferredoxin---NADP+ reductase
# TYRA                                Arogenate dehydrogenase
# MPOMC2     magnesium-protoporphyrin-IX 13-monomethyl est...
# MPOMMM2   Magnesium-protoporphyrin-IX 13-monomethyl este...
# MPOMOR2    magnesium-protoporphyrin-IX 13-monomethyl est...
# PHYTEDH2                          Phytoene dehydrogenase(2)
# PHYTFDH2                       Phytofluene dehydrogenase(2)
# SSALy           Succinate-semialdehyde dehydrogenase (NADP)
#
#                                                   subsystem      flux  \
# G6PDH2r                           Pentose phosphate pathway  0.225663
# GND                               Pentose phosphate pathway  0.135496
# ICDHyr                            Citrate cycle (TCA cycle)  0.070033
# ME2                                     Pyruvate metabolism  0.047587
# MTHFD               Glyoxylate and dicarboxylate metabolism  0.041078
# FNOR                                         Photosynthesis  0.016570
# TYRA      Phenylalanine tyrosine and tryptophan biosynth...  0.007537
# MPOMC2                 Porphyrin and chlorophyll metabolism  0.001190
# MPOMMM2                Porphyrin and chlorophyll metabolism  0.001190
# MPOMOR2                Porphyrin and chlorophyll metabolism  0.001190
# PHYTEDH2                            Carotenoid Biosynthesis  0.000587
# PHYTFDH2                            Carotenoid Biosynthesis  0.000587
# SSALy                   C5-Branched dibasic acid metabolism  0.000006
#
#             percent    minimum    maximum  \
# G6PDH2r   41.126016   0.000000  10.401153
# GND       24.693422   0.000000  10.352270
# ICDHyr    12.763192   0.066532   4.458026
# ME2        8.672468   0.000000  15.508843
# MTHFD      7.486210   0.000000   0.041078
# FNOR       3.019719 -30.101213  22.224995
# TYRA       1.373553   0.000000   0.007566
# MPOMC2     0.216796   0.000000   0.001190
# MPOMMM2    0.216796   0.000000   0.001190
# MPOMOR2    0.216796   0.000000   0.001190
# PHYTEDH2   0.107014   0.000000   0.000587
# PHYTFDH2   0.107014   0.000000   0.000587
# SSALy      0.001005   0.000005   4.391890
#
#                                                      string
# G6PDH2r           g6p_c + nadp_c --> 6pgl_c + h_c + nadph_c
# GND         6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c
# ICDHyr          icit_c + nadp_c --> akg_c + co2_c + nadph_c
# ME2           mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c
# MTHFD                mlthf_c + nadp_c --> methf_c + nadph_c
# FNOR      2.0 fdxrd_c + h_c + nadp_c <=> 2.0 fdxo_2_2_c ...
# TYRA      Largn_c + nadp_c --> co2_c + h_c + nadph_c + t...
# MPOMC2    h2o_c + mppp9om_c + nadp_c --> h_c + hmppp9_c ...
# MPOMMM2      hmppp9_c + nadp_c --> h_c + nadph_c + omppp9_c
# MPOMOR2    nadp_c + omppp9_c --> dvpchlld_c + h_c + nadph_c
# PHYTEDH2     nadp_c + phytoe_c --> h_c + nadph_c + phytof_c
# PHYTFDH2    nadp_c + phytof_c --> h_c + nadph_c + zcarote_c
# SSALy     h2o_c + nadp_c + sucsal_c <=> 2.0 h_c + nadph_...

# %%
df_nadph_consume.sort_values(by='percent', ascending=False)
# Out:
#                                                            desciption  \
# ASAD                             Aspartate-semialdehyde dehydrogenase
# KARA1               Ketol-acid reductoisomerase (2,3-dihydroxy-3-m...
# 3OAR40              3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 3OAR100             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 3OAR80              3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR80y              Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR60y              Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR40y              Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR60              3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR120y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR120             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR100y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR140             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# SHK3Dr                                        Shikimate dehydrogenase
# EAR160y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR140y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR160             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# KARA2                    Ketol-acid reductoisomerase (2-Acetolactate)
# AGPR                          N-acetyl-g-glutamyl-phosphate reductase
# G5SD                           Glutamate-5-semialdehyde dehydrogenase
# DHDPRy                          Dihydrodipicolinate reductase (NADPH)
# MECDPDH_syn         2C-methyl-D-erythritol 2,4 cyclodiphosphate de...
# DXPRIi                            1-deoxy-D-xylulose reductoisomerase
# GLUTRR                                        Glutamyl-tRNA reductase
# IPDPS_syn           1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate...
# 3OAR180             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR180y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# GGDPR                            Geranylgeranyl diphosphate reductase
# DMPPS_syn           1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate...
# DHFR                                          Dihydrofolate reductase
# UAPGR                   UDP-N-acetylenolpyruvoylglucosamine reductase
# 3OAR121             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 3OAR141             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR161y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR141y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR121y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR161             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# DVOCHR                Divinyl protochlorophyllide a 8-vinyl-reductase
# POR_1                             Protochlorophyllide oxidoreductase
# ZCAROTDH1                                    Zeta-carotene desaturase
# ZCAROTDH2                                 Zeta-carotene desaturase(2)
# EAR181y             Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR181             3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# BCAROHX2                                    Beta-carotene hydroxylase
# BCAROHX                                     Beta-carotene hydroxylase
# DPR                                     2-dehydropantoate 2-reductase
# APRAUR              5-amino-6-(5-phosphoribosylamino)uracil reductase
# BIOMASS_Ec_SynMixo                       Mixotrophic Biomass Ecuation
# PC6AR                                          Precorrin-6A reductase
#
#                                                             subsystem  \
# ASAD                      Alanine, aspartate and glutamate metabolism
# KARA1                      Valine leucine and isoleucine biosynthesis
# 3OAR40                                        Fatty acid biosynthesis
# 3OAR100                                       Fatty acid biosynthesis
# 3OAR80                                        Fatty acid biosynthesis
# EAR80y                                        Fatty acid biosynthesis
# EAR60y                                        Fatty acid biosynthesis
# EAR40y                                        Fatty acid biosynthesis
# 3OAR60                                        Fatty acid biosynthesis
# EAR120y                                       Fatty acid biosynthesis
# 3OAR120                                       Fatty acid biosynthesis
# EAR100y                                       Fatty acid biosynthesis
# 3OAR140                                       Fatty acid biosynthesis
# SHK3Dr              Phenylalanine tyrosine and tryptophan biosynth...
# EAR160y                                       Fatty acid biosynthesis
# EAR140y                                       Fatty acid biosynthesis
# 3OAR160                                       Fatty acid biosynthesis
# KARA2                      Valine leucine and isoleucine biosynthesis
# AGPR                        Urea cycle and metabolism of amino groups
# G5SD                        Urea cycle and metabolism of amino groups
# DHDPRy                                              Lysine metabolism
# MECDPDH_syn                           Terpenoid backbone biosynthesis
# DXPRIi                                            Sterol biosynthesis
# GLUTRR                           Porphyrin and chlorophyll metabolism
# IPDPS_syn                             Terpenoid backbone biosynthesis
# 3OAR180                                       Fatty acid biosynthesis
# EAR180y                                       Fatty acid biosynthesis
# GGDPR                                 Terpenoid backbone biosynthesis
# DMPPS_syn                             Terpenoid backbone biosynthesis
# DHFR                                              Folate biosynthesis
# UAPGR                                          Aminosugars metabolism
# 3OAR121                                       Fatty acid biosynthesis
# 3OAR141                                       Fatty acid biosynthesis
# EAR161y                                       Fatty acid biosynthesis
# EAR141y                                       Fatty acid biosynthesis
# EAR121y                                       Fatty acid biosynthesis
# 3OAR161                                       Fatty acid biosynthesis
# DVOCHR                           Porphyrin and chlorophyll metabolism
# POR_1                            Porphyrin and chlorophyll metabolism
# ZCAROTDH1                                     Carotenoid Biosynthesis
# ZCAROTDH2                                     Carotenoid Biosynthesis
# EAR181y                                       Fatty acid biosynthesis
# 3OAR181                                       Fatty acid biosynthesis
# BCAROHX2                                      Carotenoid Biosynthesis
# BCAROHX                                       Carotenoid Biosynthesis
# DPR                                 Pantothenate and CoA biosynthesis
# APRAUR                                          Riboflavin metabolism
# BIOMASS_Ec_SynMixo                  Biomass and maintenance functions
# PC6AR                            Porphyrin and chlorophyll metabolism
#
#                         flux   percent    minimum   maximum  \
# ASAD               -0.048107  8.767244  -0.048107 -0.045702
# KARA1              -0.046917  8.550446  -0.046917 -0.044571
# 3OAR40             -0.023331  4.251912  -0.023331 -0.022164
# 3OAR100            -0.023331  4.251912  -0.023331 -0.022164
# 3OAR80             -0.023331  4.251912  -0.023331 -0.022164
# EAR80y             -0.023331  4.251912  -0.023331 -0.022164
# EAR60y             -0.023331  4.251912  -0.023331 -0.022164
# EAR40y             -0.023331  4.251912  -0.023331 -0.022164
# 3OAR60             -0.023331  4.251912  -0.023331 -0.022164
# EAR120y            -0.022100  4.027631  -0.022100 -0.020995
# 3OAR120            -0.022100  4.027631  -0.022100 -0.020995
# EAR100y            -0.022100  4.027631  -0.022100 -0.020995
# 3OAR140            -0.022100  4.027631  -0.022100 -0.020995
# SHK3Dr             -0.022093  4.026364  -0.022093 -0.020988
# EAR160y            -0.016435  2.995246  -0.016435 -0.015614
# EAR140y            -0.016435  2.995246  -0.016435 -0.015614
# 3OAR160            -0.016435  2.995246  -0.016435 -0.015614
# KARA2              -0.016217  2.955503  -0.016217 -0.015406
# AGPR               -0.015267  2.782343 -22.327087 -0.014504
# G5SD               -0.013254  2.415534 -22.312544  0.000000
# DHDPRy             -0.012228  2.228499  -0.012228 -0.011617
# MECDPDH_syn        -0.010049  1.831410  -0.010049 -0.009547
# DXPRIi             -0.010049  1.831410  -0.010049 -0.009547
# GLUTRR             -0.009917  1.807396  -0.009917 -0.009422
# IPDPS_syn          -0.007536  1.373375  -0.010049  0.000000
# 3OAR180            -0.007119  1.297395  -0.007119 -0.006763
# EAR180y            -0.007119  1.297395  -0.007119 -0.006763
# GGDPR              -0.003933  0.716691  -0.003933 -0.003736
# DMPPS_syn          -0.002513  0.458035  -0.010049  0.000000
# DHFR               -0.001532  0.279239  -0.001532 -0.001456
# UAPGR              -0.001416  0.258096  -0.001416 -0.001345
# 3OAR121            -0.001231  0.224281  -0.001231 -0.001169
# 3OAR141            -0.001231  0.224281  -0.001231 -0.001169
# EAR161y            -0.001231  0.224281  -0.001231 -0.001169
# EAR141y            -0.001231  0.224281  -0.001231 -0.001169
# EAR121y            -0.001231  0.224281  -0.001231 -0.001169
# 3OAR161            -0.001231  0.224281  -0.001231 -0.001169
# DVOCHR             -0.001190  0.216796  -0.001190 -0.001130
# POR_1              -0.001190  0.216796  -0.001190 -0.001130
# ZCAROTDH1          -0.000587  0.107014  -0.000587 -0.000558
# ZCAROTDH2          -0.000587  0.107014  -0.000587 -0.000558
# EAR181y            -0.000535  0.097524  -0.000535 -0.000508
# 3OAR181            -0.000535  0.097524  -0.000535 -0.000508
# BCAROHX2           -0.000163  0.029726  -0.000163 -0.000155
# BCAROHX            -0.000163  0.029726  -0.000163 -0.000155
# DPR                -0.000032  0.005893  -0.000032 -0.000031
# APRAUR             -0.000025  0.004569  -0.000025 -0.000024
# BIOMASS_Ec_SynMixo -0.000019  0.003427  -0.000019 -0.000018
# PC6AR              -0.000013  0.002281  -0.000013 -0.000012
#
#                                                                string
# ASAD                aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + na...
# KARA1                 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c
# 3OAR40                 actACP_c + h_c + nadph_c <=> 3haACP_c + nadp_c
# 3OAR100             3odecACP_c + h_c + nadph_c <=> 3hdecACP_c + na...
# 3OAR80              3ooctACP_c + h_c + nadph_c <=> 3hoctACP_c + na...
# EAR80y               h_c + nadph_c + toct2eACP_c --> nadp_c + ocACP_c
# EAR60y              h_c + nadph_c + thex2eACP_c --> hexACP_c + nadp_c
# EAR40y               but2eACP_c + h_c + nadph_c --> butACP_c + nadp_c
# 3OAR60              3ohexACP_c + h_c + nadph_c <=> 3hhexACP_c + na...
# EAR120y             h_c + nadph_c + tddec2eACP_c --> ddcaACP_c + n...
# 3OAR120             3oddecACP_c + h_c + nadph_c <=> 3hddecACP_c + ...
# EAR100y             h_c + nadph_c + tdec2eACP_c --> dcaACP_c + nadp_c
# 3OAR140             3omrsACP_c + h_c + nadph_c --> 3hmrsACP_c + na...
# SHK3Dr                     3dhsk_c + h_c + nadph_c --> nadp_c + skm_c
# EAR160y             h_c + nadph_c + tpalm2eACP_c --> nadp_c + palm...
# EAR140y             h_c + nadph_c + tmrs2eACP_c --> myrsACP_c + na...
# 3OAR160             3opalmACP_c + h_c + nadph_c <=> 3hpalmACP_c + ...
# KARA2                  2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c
# AGPR                acg5sa_c + nadp_c + pi_c <=> acg5p_c + h_c + n...
# G5SD                glu5p_c + h_c + nadph_c --> glu5sa_c + nadp_c ...
# DHDPRy                   23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c
# MECDPDH_syn          2mecdp_c + nadph_c --> h2mb4p_c + h2o_c + nadp_c
# DXPRIi                  dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
# GLUTRR              glutrna_c + h_c + nadph_c --> glu1sa_c + nadp_...
# IPDPS_syn           h2mb4p_c + h_c + nadph_c --> h2o_c + ipdp_c + ...
# 3OAR180             3ooctdACP_c + h_c + nadph_c --> 3hoctaACP_c + ...
# EAR180y             h_c + nadph_c + toctd2eACP_c --> nadp_c + ocdc...
# GGDPR               ggdp_c + 3.0 h_c + 3.0 nadph_c --> 3.0 nadp_c ...
# DMPPS_syn           h2mb4p_c + h_c + nadph_c --> dmpp_c + h2o_c + ...
# DHFR                         dhf_c + h_c + nadph_c <=> nadp_c + thf_c
# UAPGR                     h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
# 3OAR121             3ocddec5eACP_c + h_c + nadph_c --> 3hcddec5eAC...
# 3OAR141             3ocmrs7eACP_c + h_c + nadph_c --> 3hcmrs7eACP_...
# EAR161y             h_c + nadph_c + t3c9palmeACP_c --> hdeACP_c + ...
# EAR141y             h_c + nadph_c + t3c7mrseACP_c --> nadp_c + tde...
# EAR121y             h_c + nadph_c + t3c5ddeceACP_c --> cddec5eACP_...
# 3OAR161             3ocpalm9eACP_c + h_c + nadph_c --> 3hcpalm9eAC...
# DVOCHR               dvpchlld_c + h_c + nadph_c --> nadp_c + pchlld_c
# POR_1                   h_c + nadph_c + pchlld_c --> chlld_c + nadp_c
# ZCAROTDH1           h_c + nadph_c + o2_c + zcarote_c --> 2.0 h2o_c...
# ZCAROTDH2           h_c + nadph_c + neuspn_c + o2_c --> 2.0 h2o_c ...
# EAR181y             h_c + nadph_c + t3c11vaceACP_c --> nadp_c + oc...
# 3OAR181             3ocvac11eACP_c + h_c + nadph_c --> 3hcvac11eAC...
# BCAROHX2            bcryptox_c + h_c + nadph_c + o2_c --> h2o_c + ...
# BCAROHX             caro_c + h_c + nadph_c + o2_c --> bcryptox_c +...
# DPR                     2dhp_c + h_c + nadph_c --> nadp_c + pant__R_c
# APRAUR                  5apru_c + h_c + nadph_c --> 5aprbu_c + nadp_c
# BIOMASS_Ec_SynMixo  0.000223 10fthf_c + 0.000223 5mthf_c + 0.00027...
# PC6AR                    h_c + nadph_c + pre6a_c --> nadp_c + pre6b_c

# %%
#NADP

df_nadp = model.metabolites.nadp_c.summary(fva=0.95).to_frame()
rxn_name_nadp = []
rxn_subsystem_nadp = []
rxn_string_nadp = []

rxn_nadp = df_nadp['reaction'].tolist()
for i in range(len(rxn_nadp)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_nadp[i]:
            name_nadp = model.reactions[j].name
            rxn_name_nadp.append(name_nadp)
            subsystem_nadp = model.reactions[j].subsystem
            rxn_subsystem_nadp.append(subsystem_nadp)
            string_nadp = model.reactions[j].build_reaction_string()
            rxn_string_nadp.append(string_nadp)
df_nadp.insert(0, 'desciption', rxn_name_nadp)
df_nadp.insert(1, 'subsystem', rxn_subsystem_nadp)
df_nadp.insert(7, 'string', rxn_string_nadp)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_nadp_produce = df_nadp.loc[((df_nadp["flux"] > 0) & ((df_nadp["factor"] > 0) | (df_nadp["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_nadp_consume = df_nadp.loc[((df_nadp["flux"] < 0) & ((df_nadp["factor"] < 0) | (df_nadp["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_nadp_produce = (df_nadp_produce['flux'] / 
                  df_nadp_produce['flux'].sum()) * 100
df_nadp_produce.insert(3, 'percent', percent_nadp_produce)

percent_nadp_consume = (df_nadp_consume['flux'] / 
                  df_nadp_consume['flux'].sum()) * 100
df_nadp_consume.insert(3, 'percent', percent_nadp_consume)

# %%
df_nadp_produce.sort_values(by='percent', ascending=False)
# Out:
#                                                     desciption  \
# ASAD                      Aspartate-semialdehyde dehydrogenase
# KARA1        Ketol-acid reductoisomerase (2,3-dihydroxy-3-m...
# 3OAR40       3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 3OAR100      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 3OAR80       3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR80y       Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR60y       Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR40y       Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR60       3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 3OAR120      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR100y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR120y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR140      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# SHK3Dr                                 Shikimate dehydrogenase
# EAR140y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR160      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR160y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# KARA2             Ketol-acid reductoisomerase (2-Acetolactate)
# AGPR                   N-acetyl-g-glutamyl-phosphate reductase
# G5SD                    Glutamate-5-semialdehyde dehydrogenase
# DHDPRy                   Dihydrodipicolinate reductase (NADPH)
# MECDPDH_syn  2C-methyl-D-erythritol 2,4 cyclodiphosphate de...
# DXPRIi                     1-deoxy-D-xylulose reductoisomerase
# GLUTRR                                 Glutamyl-tRNA reductase
# IPDPS_syn    1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate...
# EAR180y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR180      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# GGDPR                     Geranylgeranyl diphosphate reductase
# DMPPS_syn    1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate...
# DHFR                                   Dihydrofolate reductase
# UAPGR            UDP-N-acetylenolpyruvoylglucosamine reductase
# 3OAR121      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR141y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# EAR121y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR141      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# EAR161y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR161      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# DVOCHR         Divinyl protochlorophyllide a 8-vinyl-reductase
# POR_1                      Protochlorophyllide oxidoreductase
# ZCAROTDH1                             Zeta-carotene desaturase
# ZCAROTDH2                          Zeta-carotene desaturase(2)
# EAR181y      Enoyl-[acyl-carrier-protein] reductase (NADPH)...
# 3OAR181      3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# BCAROHX2                             Beta-carotene hydroxylase
# BCAROHX                              Beta-carotene hydroxylase
# DPR                              2-dehydropantoate 2-reductase
# NADK                                                NAD kinase
# APRAUR       5-amino-6-(5-phosphoribosylamino)uracil reductase
# PC6AR                                   Precorrin-6A reductase
#
#                                                      subsystem      flux  \
# ASAD               Alanine, aspartate and glutamate metabolism  0.048107
# KARA1               Valine leucine and isoleucine biosynthesis  0.046917
# 3OAR40                                 Fatty acid biosynthesis  0.023331
# 3OAR100                                Fatty acid biosynthesis  0.023331
# 3OAR80                                 Fatty acid biosynthesis  0.023331
# EAR80y                                 Fatty acid biosynthesis  0.023331
# EAR60y                                 Fatty acid biosynthesis  0.023331
# EAR40y                                 Fatty acid biosynthesis  0.023331
# 3OAR60                                 Fatty acid biosynthesis  0.023331
# 3OAR120                                Fatty acid biosynthesis  0.022100
# EAR100y                                Fatty acid biosynthesis  0.022100
# EAR120y                                Fatty acid biosynthesis  0.022100
# 3OAR140                                Fatty acid biosynthesis  0.022100
# SHK3Dr       Phenylalanine tyrosine and tryptophan biosynth...  0.022093
# EAR140y                                Fatty acid biosynthesis  0.016435
# 3OAR160                                Fatty acid biosynthesis  0.016435
# EAR160y                                Fatty acid biosynthesis  0.016435
# KARA2               Valine leucine and isoleucine biosynthesis  0.016217
# AGPR                 Urea cycle and metabolism of amino groups  0.015267
# G5SD                 Urea cycle and metabolism of amino groups  0.013254
# DHDPRy                                       Lysine metabolism  0.012228
# MECDPDH_syn                    Terpenoid backbone biosynthesis  0.010049
# DXPRIi                                     Sterol biosynthesis  0.010049
# GLUTRR                    Porphyrin and chlorophyll metabolism  0.009917
# IPDPS_syn                      Terpenoid backbone biosynthesis  0.007536
# EAR180y                                Fatty acid biosynthesis  0.007119
# 3OAR180                                Fatty acid biosynthesis  0.007119
# GGDPR                          Terpenoid backbone biosynthesis  0.003933
# DMPPS_syn                      Terpenoid backbone biosynthesis  0.002513
# DHFR                                       Folate biosynthesis  0.001532
# UAPGR                                   Aminosugars metabolism  0.001416
# 3OAR121                                Fatty acid biosynthesis  0.001231
# EAR141y                                Fatty acid biosynthesis  0.001231
# EAR121y                                Fatty acid biosynthesis  0.001231
# 3OAR141                                Fatty acid biosynthesis  0.001231
# EAR161y                                Fatty acid biosynthesis  0.001231
# 3OAR161                                Fatty acid biosynthesis  0.001231
# DVOCHR                    Porphyrin and chlorophyll metabolism  0.001190
# POR_1                     Porphyrin and chlorophyll metabolism  0.001190
# ZCAROTDH1                              Carotenoid Biosynthesis  0.000587
# ZCAROTDH2                              Carotenoid Biosynthesis  0.000587
# EAR181y                                Fatty acid biosynthesis  0.000535
# 3OAR181                                Fatty acid biosynthesis  0.000535
# BCAROHX2                               Carotenoid Biosynthesis  0.000163
# BCAROHX                                Carotenoid Biosynthesis  0.000163
# DPR                          Pantothenate and CoA biosynthesis  0.000032
# NADK                         Pantothenate and CoA biosynthesis  0.000025
# APRAUR                                   Riboflavin metabolism  0.000025
# PC6AR                     Porphyrin and chlorophyll metabolism  0.000013
#
#               percent   minimum    maximum  \
# ASAD         8.767144  0.045702   0.048107
# KARA1        8.550348  0.044571   0.046917
# 3OAR40       4.251864  0.022164   0.023331
# 3OAR100      4.251864  0.022164   0.023331
# 3OAR80       4.251864  0.022164   0.023331
# EAR80y       4.251864  0.022164   0.023331
# EAR60y       4.251864  0.022164   0.023331
# EAR40y       4.251864  0.022164   0.023331
# 3OAR60       4.251864  0.022164   0.023331
# 3OAR120      4.027585  0.020995   0.022100
# EAR100y      4.027585  0.020995   0.022100
# EAR120y      4.027585  0.020995   0.022100
# 3OAR140      4.027585  0.020995   0.022100
# SHK3Dr       4.026318  0.020988   0.022093
# EAR140y      2.995212  0.015614   0.016435
# 3OAR160      2.995212  0.015614   0.016435
# EAR160y      2.995212  0.015614   0.016435
# KARA2        2.955469  0.015406   0.016217
# AGPR         2.782312  0.014504  22.327087
# G5SD         2.415507  0.000000  22.312544
# DHDPRy       2.228474  0.011617   0.012228
# MECDPDH_syn  1.831389  0.009547   0.010049
# DXPRIi       1.831389  0.009547   0.010049
# GLUTRR       1.807376  0.009422   0.009917
# IPDPS_syn    1.373359  0.000000   0.010049
# EAR180y      1.297380  0.006763   0.007119
# 3OAR180      1.297380  0.006763   0.007119
# GGDPR        0.716683  0.003736   0.003933
# DMPPS_syn    0.458029  0.000000   0.010049
# DHFR         0.279236  0.001456   0.001532
# UAPGR        0.258093  0.001345   0.001416
# 3OAR121      0.224278  0.001169   0.001231
# EAR141y      0.224278  0.001169   0.001231
# EAR121y      0.224278  0.001169   0.001231
# 3OAR141      0.224278  0.001169   0.001231
# EAR161y      0.224278  0.001169   0.001231
# 3OAR161      0.224278  0.001169   0.001231
# DVOCHR       0.216793  0.001130   0.001190
# POR_1        0.216793  0.001130   0.001190
# ZCAROTDH1    0.107012  0.000558   0.000587
# ZCAROTDH2    0.107012  0.000558   0.000587
# EAR181y      0.097523  0.000508   0.000535
# 3OAR181      0.097523  0.000508   0.000535
# BCAROHX2     0.029726  0.000155   0.000163
# BCAROHX      0.029726  0.000155   0.000163
# DPR          0.005893  0.000031   0.000032
# NADK         0.004570  0.000024   0.000025
# APRAUR       0.004569  0.000024   0.000025
# PC6AR        0.002281  0.000012   0.000013
#
#                                                         string
# ASAD         aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + na...
# KARA1          23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c
# 3OAR40          actACP_c + h_c + nadph_c <=> 3haACP_c + nadp_c
# 3OAR100      3odecACP_c + h_c + nadph_c <=> 3hdecACP_c + na...
# 3OAR80       3ooctACP_c + h_c + nadph_c <=> 3hoctACP_c + na...
# EAR80y        h_c + nadph_c + toct2eACP_c --> nadp_c + ocACP_c
# EAR60y       h_c + nadph_c + thex2eACP_c --> hexACP_c + nadp_c
# EAR40y        but2eACP_c + h_c + nadph_c --> butACP_c + nadp_c
# 3OAR60       3ohexACP_c + h_c + nadph_c <=> 3hhexACP_c + na...
# 3OAR120      3oddecACP_c + h_c + nadph_c <=> 3hddecACP_c + ...
# EAR100y      h_c + nadph_c + tdec2eACP_c --> dcaACP_c + nadp_c
# EAR120y      h_c + nadph_c + tddec2eACP_c --> ddcaACP_c + n...
# 3OAR140      3omrsACP_c + h_c + nadph_c --> 3hmrsACP_c + na...
# SHK3Dr              3dhsk_c + h_c + nadph_c --> nadp_c + skm_c
# EAR140y      h_c + nadph_c + tmrs2eACP_c --> myrsACP_c + na...
# 3OAR160      3opalmACP_c + h_c + nadph_c <=> 3hpalmACP_c + ...
# EAR160y      h_c + nadph_c + tpalm2eACP_c --> nadp_c + palm...
# KARA2           2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c
# AGPR         acg5sa_c + nadp_c + pi_c <=> acg5p_c + h_c + n...
# G5SD         glu5p_c + h_c + nadph_c --> glu5sa_c + nadp_c ...
# DHDPRy            23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c
# MECDPDH_syn   2mecdp_c + nadph_c --> h2mb4p_c + h2o_c + nadp_c
# DXPRIi           dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
# GLUTRR       glutrna_c + h_c + nadph_c --> glu1sa_c + nadp_...
# IPDPS_syn    h2mb4p_c + h_c + nadph_c --> h2o_c + ipdp_c + ...
# EAR180y      h_c + nadph_c + toctd2eACP_c --> nadp_c + ocdc...
# 3OAR180      3ooctdACP_c + h_c + nadph_c --> 3hoctaACP_c + ...
# GGDPR        ggdp_c + 3.0 h_c + 3.0 nadph_c --> 3.0 nadp_c ...
# DMPPS_syn    h2mb4p_c + h_c + nadph_c --> dmpp_c + h2o_c + ...
# DHFR                  dhf_c + h_c + nadph_c <=> nadp_c + thf_c
# UAPGR              h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
# 3OAR121      3ocddec5eACP_c + h_c + nadph_c --> 3hcddec5eAC...
# EAR141y      h_c + nadph_c + t3c7mrseACP_c --> nadp_c + tde...
# EAR121y      h_c + nadph_c + t3c5ddeceACP_c --> cddec5eACP_...
# 3OAR141      3ocmrs7eACP_c + h_c + nadph_c --> 3hcmrs7eACP_...
# EAR161y      h_c + nadph_c + t3c9palmeACP_c --> hdeACP_c + ...
# 3OAR161      3ocpalm9eACP_c + h_c + nadph_c --> 3hcpalm9eAC...
# DVOCHR        dvpchlld_c + h_c + nadph_c --> nadp_c + pchlld_c
# POR_1            h_c + nadph_c + pchlld_c --> chlld_c + nadp_c
# ZCAROTDH1    h_c + nadph_c + o2_c + zcarote_c --> 2.0 h2o_c...
# ZCAROTDH2    h_c + nadph_c + neuspn_c + o2_c --> 2.0 h2o_c ...
# EAR181y      h_c + nadph_c + t3c11vaceACP_c --> nadp_c + oc...
# 3OAR181      3ocvac11eACP_c + h_c + nadph_c --> 3hcvac11eAC...
# BCAROHX2     bcryptox_c + h_c + nadph_c + o2_c --> h2o_c + ...
# BCAROHX      caro_c + h_c + nadph_c + o2_c --> bcryptox_c +...
# DPR              2dhp_c + h_c + nadph_c --> nadp_c + pant__R_c
# NADK                    atp_c + nad_c --> adp_c + h_c + nadp_c
# APRAUR           5apru_c + h_c + nadph_c --> 5aprbu_c + nadp_c
# PC6AR             h_c + nadph_c + pre6a_c --> nadp_c + pre6b_c

# %%
df_nadp_consume.sort_values(by='percent', ascending=False)
# Out:
#                                                            desciption  \
# G6PDH2r                             Glucose 6-phosphate dehydrogenase
# GND                                    Phosphogluconate dehydrogenase
# ICDHyr                                Isocitrate dehydrogenase (NADP)
# ME2                                               Malic enzyme (NADP)
# MTHFD                  Methylenetetrahydrofolate dehydrogenase (NADP)
# FNOR                                     Ferredoxin---NADP+ reductase
# TYRA                                          Arogenate dehydrogenase
# MPOMC2               magnesium-protoporphyrin-IX 13-monomethyl est...
# MPOMMM2             Magnesium-protoporphyrin-IX 13-monomethyl este...
# MPOMOR2              magnesium-protoporphyrin-IX 13-monomethyl est...
# PHYTEDH2                                    Phytoene dehydrogenase(2)
# PHYTFDH2                                 Phytofluene dehydrogenase(2)
# BIOMASS_Ec_SynMixo                       Mixotrophic Biomass Ecuation
# SSALy                     Succinate-semialdehyde dehydrogenase (NADP)
#
#                                                             subsystem  \
# G6PDH2r                                     Pentose phosphate pathway
# GND                                         Pentose phosphate pathway
# ICDHyr                                      Citrate cycle (TCA cycle)
# ME2                                               Pyruvate metabolism
# MTHFD                         Glyoxylate and dicarboxylate metabolism
# FNOR                                                   Photosynthesis
# TYRA                Phenylalanine tyrosine and tryptophan biosynth...
# MPOMC2                           Porphyrin and chlorophyll metabolism
# MPOMMM2                          Porphyrin and chlorophyll metabolism
# MPOMOR2                          Porphyrin and chlorophyll metabolism
# PHYTEDH2                                      Carotenoid Biosynthesis
# PHYTFDH2                                      Carotenoid Biosynthesis
# BIOMASS_Ec_SynMixo                  Biomass and maintenance functions
# SSALy                             C5-Branched dibasic acid metabolism
#
#                         flux    percent    minimum    maximum  \
# G6PDH2r            -0.225663  41.125547 -10.401153   0.000000
# GND                -0.135496  24.693140 -10.352270   0.000000
# ICDHyr             -0.070033  12.763047  -4.458026  -0.066532
# ME2                -0.047587   8.672369 -15.508843   0.000000
# MTHFD              -0.041078   7.486125  -0.041078   0.000000
# FNOR               -0.016570   3.019685 -22.224995  30.101213
# TYRA               -0.007537   1.373537  -0.007566   0.000000
# MPOMC2             -0.001190   0.216793  -0.001190   0.000000
# MPOMMM2            -0.001190   0.216793  -0.001190   0.000000
# MPOMOR2            -0.001190   0.216793  -0.001190   0.000000
# PHYTEDH2           -0.000587   0.107012  -0.000587   0.000000
# PHYTFDH2           -0.000587   0.107012  -0.000587   0.000000
# BIOMASS_Ec_SynMixo -0.000006   0.001142  -0.000006  -0.000006
# SSALy              -0.000006   0.001005  -4.391890  -0.000005
#
#                                                                string
# G6PDH2r                     g6p_c + nadp_c --> 6pgl_c + h_c + nadph_c
# GND                   6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c
# ICDHyr                    icit_c + nadp_c --> akg_c + co2_c + nadph_c
# ME2                     mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c
# MTHFD                          mlthf_c + nadp_c --> methf_c + nadph_c
# FNOR                2.0 fdxrd_c + h_c + nadp_c <=> 2.0 fdxo_2_2_c ...
# TYRA                Largn_c + nadp_c --> co2_c + h_c + nadph_c + t...
# MPOMC2              h2o_c + mppp9om_c + nadp_c --> h_c + hmppp9_c ...
# MPOMMM2                hmppp9_c + nadp_c --> h_c + nadph_c + omppp9_c
# MPOMOR2              nadp_c + omppp9_c --> dvpchlld_c + h_c + nadph_c
# PHYTEDH2               nadp_c + phytoe_c --> h_c + nadph_c + phytof_c
# PHYTFDH2              nadp_c + phytof_c --> h_c + nadph_c + zcarote_c
# BIOMASS_Ec_SynMixo  0.000223 10fthf_c + 0.000223 5mthf_c + 0.00027...
# SSALy               h2o_c + nadp_c + sucsal_c <=> 2.0 h_c + nadph_...

# %%
#NADH

df_nadh = model.metabolites.nadh_c.summary(fva=0.95).to_frame()
rxn_name_nadh = []
rxn_subsystem_nadh = []
rxn_string_nadh = []

rxn_nadh = df_nadh['reaction'].tolist()
for i in range(len(rxn_nadh)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_nadh[i]:
            name_nadh = model.reactions[j].name
            rxn_name_nadh.append(name_nadh)
            subsystem_nadh = model.reactions[j].subsystem
            rxn_subsystem_nadh.append(subsystem_nadh)
            string_nadh = model.reactions[j].build_reaction_string()
            rxn_string_nadh.append(string_nadh)
df_nadh.insert(0, 'desciption', rxn_name_nadh)
df_nadh.insert(1, 'subsystem', rxn_subsystem_nadh)
df_nadh.insert(7, 'string', rxn_string_nadh)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_nadh_produce = df_nadh.loc[((df_nadh["flux"] > 0) & ((df_nadh["factor"] > 0) | (df_nadh["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_nadh_consume = df_nadh.loc[((df_nadh["flux"] < 0) & ((df_nadh["factor"] < 0) | (df_nadh["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_nadh_produce = (df_nadh_produce['flux'] / 
                  df_nadh_produce['flux'].sum()) * 100
df_nadh_produce.insert(3, 'percent', percent_nadh_produce)

percent_nadh_consume = (df_nadh_consume['flux'] / 
                  df_nadh_consume['flux'].sum()) * 100
df_nadh_consume.insert(3, 'percent', percent_nadh_consume)

# %%
df_nadh_produce.sort_values(by='percent', ascending=False)
# Out:
#                                desciption  \
# PGCD       Phosphoglycerate dehydrogenase
# IPMD      3-isopropylmalate dehydrogenase
# HISTD            Histidinol dehydrogenase
# IMPD                    IMP dehydrogenase
# GLYCLc            Glycine Cleavage System
# GCALDD       Glycolaldehyde dehydrogenase
# GLYCLTDx    Glycolate dehydrogenase (NAD)
# PPND             Prephenate dehydrogenase
#
#                                                   subsystem      flux  \
# PGCD                        Arginine and proline metabolism  0.081614
# IPMD             Valine leucine and isoleucine biosynthesis  0.029472
# HISTD                                  Histidine metabolism  0.009616
# IMPD                                      Purine metabolism  0.008871
# GLYCLc                                     Photorespiration  0.006105
# GCALDD                                               Others  0.000050
# GLYCLTDx            Glyoxylate and dicarboxylate metabolism  0.000050
# PPND      Phenylalanine tyrosine and tryptophan biosynth...  0.000029
#
#             percent   minimum    maximum  \
# PGCD      60.095744  0.000000  10.111282
# IPMD      21.701453  0.027998   0.029472
# HISTD      7.080657  0.009135   0.009616
# IMPD       6.531858  0.008427   0.008871
# GLYCLc     4.495165 -0.027526   1.835971
# GCALDD     0.036897  0.000048   0.000048
# GLYCLTDx   0.036897  0.000000   3.749891
# PPND       0.021327  0.000000   0.007566
#
#                                                      string
# PGCD                3pg_c + nad_c --> 3php_c + h_c + nadh_c
# IPMD           3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c
# HISTD     h2o_c + histd_c + 2.0 nad_c --> 3.0 h_c + his_...
# IMPD         h2o_c + imp_c + nad_c --> h_c + nadh_c + xmp_c
# GLYCLc         dhlprot_c + nad_c <=> h_c + lprot_c + nadh_c
# GCALDD    gcald_c + h2o_c + nad_c --> glyclt_c + 2.0 h_c...
# GLYCLTDx          glx_c + h_c + nadh_c <-- glyclt_c + nad_c
# PPND            nad_c + pphn_c --> 34hpp_c + co2_c + nadh_c

# %%
df_nadh_consume.sort_values(by='percent', ascending=False)
# Out:
#                                                          desciption  \
# GLUSx                                    Glutamate synthase  NADH2
# HSDxi                 Homoserine dehydrogenase  NADH   irreversible
# ALAD_L                                      L-alanine dehydrogenase
# P5CRx                       Pyrroline-5-carboxylate reductase(nadh)
# G3PD1ir                    Glycerol 3 phosphate dehydrogenase  NAD
# MTHFR2              5,10-methylenetetrahydrofolate reductase (NADH)
# TRSARr                            Tartronate semialdehyde reductase
# CYRDAR                     Cob(II)yrinic acid a,c-diamide reductase
# BIOMASS_Ec_SynMixo                     Mixotrophic Biomass Ecuation
#
#                                                       subsystem      flux  \
# GLUSx                                       Nitrogen metabolism -0.043845
# HSDxi                                         Lysine metabolism -0.035879
# ALAD_L              Alanine, aspartate and glutamate metabolism -0.026184
# P5CRx                           Arginine and proline metabolism -0.013254
# G3PD1ir                                 Glycerolipid metabolism -0.009726
# MTHFR2                                      Folate biosynthesis -0.006885
# TRSARr                  Glyoxylate and dicarboxylate metabolism -0.000025
# CYRDAR                     Porphyrin and chlorophyll metabolism -0.000006
# BIOMASS_Ec_SynMixo            Biomass and maintenance functions -0.000003
#
#                       percent    minimum   maximum  \
# GLUSx               32.285102 -30.784219  0.000000
# HSDxi               26.419024  -0.035879 -0.034085
# ALAD_L              19.280196  -3.292890  0.000000
# P5CRx                9.759681  -0.013254  0.000000
# G3PD1ir              7.161559  -0.009726  3.491965
# MTHFR2               5.069534  -0.120541 -0.006541
# TRSARr               0.018449  -1.886423  0.000000
# CYRDAR               0.004609  -0.000006 -0.000006
# BIOMASS_Ec_SynMixo   0.001846  -0.000003 -0.000002
#
#                                                                string
# GLUSx               akg_c + gln__L_c + h_c + nadh_c --> 2.0 glu__L...
# HSDxi                     aspsa_c + h_c + nadh_c <=> hom__L_c + nad_c
# ALAD_L              ala__L_c + h2o_c + nad_c <-- h_c + nadh_c + nh...
# P5CRx                1pyr5c_c + 2.0 h_c + nadh_c --> nad_c + pro__L_c
# G3PD1ir                    dhap_c + h_c + nadh_c <=> glyc3p_c + nad_c
# MTHFR2                 2.0 h_c + mlthf_c + nadh_c --> 5mthf_c + nad_c
# TRSARr                2h3oppan_c + h_c + nadh_c <=> glyc__R_c + nad_c
# CYRDAR              2.0 co2dam_c + nadh_c --> 2.0 co1dam_c + h_c +...
# BIOMASS_Ec_SynMixo  0.000223 10fthf_c + 0.000223 5mthf_c + 0.00027...

# %%
#NAD

df_nad = model.metabolites.nad_c.summary(fva=0.95).to_frame()
rxn_name_nad = []
rxn_subsystem_nad = []
rxn_string_nad = []

rxn_nad = df_nad['reaction'].tolist()
for i in range(len(rxn_nad)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_nad[i]:
            name_nad = model.reactions[j].name
            rxn_name_nad.append(name_nad)
            subsystem_nad = model.reactions[j].subsystem
            rxn_subsystem_nad.append(subsystem_nad)
            string_nad = model.reactions[j].build_reaction_string()
            rxn_string_nad.append(string_nad)
df_nad.insert(0, 'desciption', rxn_name_nad)
df_nad.insert(1, 'subsystem', rxn_subsystem_nad)
df_nad.insert(7, 'string', rxn_string_nad)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_nad_produce = df_nad.loc[((df_nad["flux"] > 0) & ((df_nad["factor"] > 0) | (df_nad["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_nad_consume = df_nad.loc[((df_nad["flux"] < 0) & ((df_nad["factor"] < 0) | (df_nad["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_nad_produce = (df_nad_produce['flux'] / 
                  df_nad_produce['flux'].sum()) * 100
df_nad_produce.insert(3, 'percent', percent_nad_produce)

percent_nad_consume = (df_nad_consume['flux'] / 
                  df_nad_consume['flux'].sum()) * 100
df_nad_consume.insert(3, 'percent', percent_nad_consume)

# %%
df_nad_produce.sort_values(by='percent', ascending=False)
# Out:
#                                               desciption  \
# GLUSx                         Glutamate synthase  NADH2
# HSDxi      Homoserine dehydrogenase  NADH   irreversible
# ALAD_L                           L-alanine dehydrogenase
# P5CRx            Pyrroline-5-carboxylate reductase(nadh)
# G3PD1ir         Glycerol 3 phosphate dehydrogenase  NAD
# MTHFR2   5,10-methylenetetrahydrofolate reductase (NADH)
# NADS2      Nicotinate-mononucleotide adenylyltransferase
# TRSARr                 Tartronate semialdehyde reductase
# CYRDAR          Cob(II)yrinic acid a,c-diamide reductase
#
#                                            subsystem      flux    percent  \
# GLUSx                            Nitrogen metabolism  0.043845  32.255325
# HSDxi                              Lysine metabolism  0.035879  26.394657
# ALAD_L   Alanine, aspartate and glutamate metabolism  0.026184  19.262414
# P5CRx                Arginine and proline metabolism  0.013254   9.750680
# G3PD1ir                      Glycerolipid metabolism  0.009726   7.154954
# MTHFR2                           Folate biosynthesis  0.006885   5.064858
# NADS2                           Glutamate metabolism  0.000128   0.094077
# TRSARr       Glyoxylate and dicarboxylate metabolism  0.000025   0.018432
# CYRDAR          Porphyrin and chlorophyll metabolism  0.000006   0.004605
#
#           minimum    maximum  \
# GLUSx    0.000000  30.786890
# HSDxi    0.034085   0.035879
# ALAD_L   0.000000   3.292890
# P5CRx    0.000000   0.013254
# G3PD1ir -3.491965   0.009726
# MTHFR2   0.006541   0.120541
# NADS2    0.000121   0.000128
# TRSARr   0.000000   1.886423
# CYRDAR   0.000006   0.000006
#
#                                                     string
# GLUSx    akg_c + gln__L_c + h_c + nadh_c --> 2.0 glu__L...
# HSDxi          aspsa_c + h_c + nadh_c <=> hom__L_c + nad_c
# ALAD_L   ala__L_c + h2o_c + nad_c <-- h_c + nadh_c + nh...
# P5CRx     1pyr5c_c + 2.0 h_c + nadh_c --> nad_c + pro__L_c
# G3PD1ir         dhap_c + h_c + nadh_c <=> glyc3p_c + nad_c
# MTHFR2      2.0 h_c + mlthf_c + nadh_c --> 5mthf_c + nad_c
# NADS2    atp_c + dnad_c + gln__L_c + h2o_c --> amp_c + ...
# TRSARr     2h3oppan_c + h_c + nadh_c <=> glyc__R_c + nad_c
# CYRDAR   2.0 co2dam_c + nadh_c --> 2.0 co1dam_c + h_c +...

# %%
df_nad_consume.sort_values(by='percent', ascending=False)
# Out:
#                                          desciption  \
# PGCD                 Phosphoglycerate dehydrogenase
# IPMD                3-isopropylmalate dehydrogenase
# HISTD                      Histidinol dehydrogenase
# IMPD                              IMP dehydrogenase
# GLYCLc                      Glycine Cleavage System
# BIOMASS_Ec_SynMixo     Mixotrophic Biomass Ecuation
# GCALDD                 Glycolaldehyde dehydrogenase
# GLYCLTDx              Glycolate dehydrogenase (NAD)
# PPND                       Prephenate dehydrogenase
# NADK                                     NAD kinase
#
#                                                             subsystem  \
# PGCD                                  Arginine and proline metabolism
# IPMD                       Valine leucine and isoleucine biosynthesis
# HISTD                                            Histidine metabolism
# IMPD                                                Purine metabolism
# GLYCLc                                               Photorespiration
# BIOMASS_Ec_SynMixo                  Biomass and maintenance functions
# GCALDD                                                         Others
# GLYCLTDx                      Glyoxylate and dicarboxylate metabolism
# PPND                Phenylalanine tyrosine and tryptophan biosynth...
# NADK                                Pantothenate and CoA biosynthesis
#
#                         flux    percent    minimum   maximum  \
# PGCD               -0.081614  60.040317 -10.111282  0.000000
# IPMD               -0.029472  21.681438  -0.029472 -0.027998
# HISTD              -0.009616   7.074126  -0.009616 -0.009135
# IMPD               -0.008871   6.525834  -0.008871 -0.008427
# GLYCLc             -0.006105   4.491019  -1.835971  0.027526
# BIOMASS_Ec_SynMixo -0.000100   0.073786  -0.000100 -0.000095
# GCALDD             -0.000050   0.036863  -0.000048 -0.000048
# GLYCLTDx           -0.000050   0.036863  -3.749891  0.000000
# PPND               -0.000029   0.021308  -0.007566  0.000000
# NADK               -0.000025   0.018446  -0.000024 -0.000024
#
#                                                                string
# PGCD                          3pg_c + nad_c --> 3php_c + h_c + nadh_c
# IPMD                     3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c
# HISTD               h2o_c + histd_c + 2.0 nad_c --> 3.0 h_c + his_...
# IMPD                   h2o_c + imp_c + nad_c --> h_c + nadh_c + xmp_c
# GLYCLc                   dhlprot_c + nad_c <=> h_c + lprot_c + nadh_c
# BIOMASS_Ec_SynMixo  0.000223 10fthf_c + 0.000223 5mthf_c + 0.00027...
# GCALDD              gcald_c + h2o_c + nad_c --> glyclt_c + 2.0 h_c...
# GLYCLTDx                    glx_c + h_c + nadh_c <-- glyclt_c + nad_c
# PPND                      nad_c + pphn_c --> 34hpp_c + co2_c + nadh_c
# NADK                           atp_c + nad_c --> adp_c + h_c + nadp_c

# %%
#CO2

df_co2 = model.metabolites.co2_c.summary(fva=0.95).to_frame()
rxn_name_co2 = []
rxn_subsystem_co2 = []
rxn_string_co2 = []

rxn_co2 = df_co2['reaction'].tolist()
for i in range(len(rxn_co2)):
    for j in range(len(model.reactions)):
        if model.reactions[j].id == rxn_co2[i]:
            name_co2 = model.reactions[j].name
            rxn_name_co2.append(name_co2)
            subsystem_co2 = model.reactions[j].subsystem
            rxn_subsystem_co2.append(subsystem_co2)
            string_co2 = model.reactions[j].build_reaction_string()
            rxn_string_co2.append(string_co2)
df_co2.insert(0, 'desciption', rxn_name_co2)
df_co2.insert(1, 'subsystem', rxn_subsystem_co2)
df_co2.insert(7, 'string', rxn_string_co2)

#create dataframe from producing fluxes where the metabolite is a product in the reaction.
df_co2_produce = df_co2.loc[((df_co2["flux"] > 0) & ((df_co2["factor"] > 0) | (df_co2["factor"] < 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#create dataframe from consuming fluxes where the metabolite is a substrate in the reaction.
df_co2_consume = df_co2.loc[((df_co2["flux"] < 0) & ((df_co2["factor"] < 0) | (df_co2["factor"] > 0))), ['desciption', 'subsystem', 'flux', 'minimum', 'maximum','string']]

#add flux percentage
percent_co2_produce = (df_co2_produce['flux'] / 
                  df_co2_produce['flux'].sum()) * 100
df_co2_produce.insert(3, 'percent', percent_co2_produce)

percent_co2_consume = (df_co2_consume['flux'] / 
                  df_co2_consume['flux'].sum()) * 100
df_co2_consume.insert(3, 'percent', percent_co2_consume)

# %%
df_co2_produce.sort_values(by='percent', ascending=False)
# Out:
#                                                 desciption  \
# GND                         Phosphogluconate dehydrogenase
# ICDHyr                     Isocitrate dehydrogenase (NADP)
# ME2                                    Malic enzyme (NADP)
# ACLS                                 Acetolactate synthase
# OMCDC    2-Oxo-4-methyl-3-carboxypentanoate decarboxyla...
# KAS15                       Beta-ketoacyl-ACP synthase (2)
# 3OAS80   3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# 3OAS100  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# 3OAS60   3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# 3OAS120  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# 3OAS140  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# OMPDC                 Orotidine-5'-phosphate decarboxylase
# 3OAS160  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# ACHBS                  2-aceto-2-hydroxybutanoate synthase
# DAPDC                        Diaminopimelate decarboxylase
# PPNDH                               Prephenate dehydratase
# DXPS               1-deoxy-D-xylulose 5-phosphate synthase
# TYRA                               Arogenate dehydrogenase
# 3OAS180  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# GLYCLa                             Glycine Cleavage System
# UPPDC1   Uroporphyrinogen decarboxylase (uroporphyrinog...
# IGPS                  Indole-3-glycerol-phosphate synthase
# CPPPGO            Coproporphyrinogen oxidase (O2 required)
# UREA                                                Urease
# ARGDC                               Arginine decarboxylase
# 3OAS161  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# 3OAS141  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# 3OAS121  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# 3OAS181  3-oxoacyl-[acyl-carrier-protein] synthase (n-C...
# ADMDC                     Adenosylmethionine decarboxylase
# NNDPR    Nicotinate-nucleotide diphosphorylase (carboxy...
# DHNAPHT       1,4-dihydroxy-2-naphthoate phytyltransferase
# OXGDC2                        2-oxoglutarate decarboxylase
# PPCDC            Phosphopantothenoylcysteine decarboxylase
# ASP1DC                           Aspartate 1-decarboxylase
# PPND                              Prephenate dehydrogenase
# 34HPPOR       4 Hydroxyphenylpyruvateoxygen oxidoreductase
# HGPHT                     Homogenitisate phytyltransferase
# GLXCL                               Glyoxalate carboligase
# PC6YM    Precorrin-6Y C5,15-methyltransferase (decarbox...
# THRPDC                 L threonine phosphate decarboxylase
# OXGDC                         2-oxoglutarate decarboxylase
#
#                                                  subsystem      flux  \
# GND                              Pentose phosphate pathway  0.135496
# ICDHyr                           Citrate cycle (TCA cycle)  0.070033
# ME2                                    Pyruvate metabolism  0.047587
# ACLS                   C5-Branched dibasic acid metabolism  0.046917
# OMCDC                                               Others  0.029472
# KAS15                              Fatty acid biosynthesis  0.023331
# 3OAS80                             Fatty acid biosynthesis  0.023331
# 3OAS100                            Fatty acid biosynthesis  0.023331
# 3OAS60                             Fatty acid biosynthesis  0.023331
# 3OAS120                            Fatty acid biosynthesis  0.022100
# 3OAS140                            Fatty acid biosynthesis  0.022100
# OMPDC                                Pyrimidine metabolism  0.017507
# 3OAS160                            Fatty acid biosynthesis  0.016435
# ACHBS           Valine leucine and isoleucine biosynthesis  0.016217
# DAPDC                                    Lysine metabolism  0.010812
# PPNDH    Phenylalanine tyrosine and tryptophan biosynth...  0.010370
# DXPS                                   Sterol biosynthesis  0.010049
# TYRA     Phenylalanine tyrosine and tryptophan biosynth...  0.007537
# 3OAS180                            Fatty acid biosynthesis  0.007119
# GLYCLa                                    Photorespiration  0.006105
# UPPDC1                Porphyrin and chlorophyll metabolism  0.004909
# IGPS     Phenylalanine tyrosine and tryptophan biosynth...  0.004002
# CPPPGO                Porphyrin and chlorophyll metabolism  0.002454
# UREA                                     Purine metabolism  0.002246
# ARGDC                      Arginine and proline metabolism  0.002246
# 3OAS161                            Fatty acid biosynthesis  0.001231
# 3OAS141                            Fatty acid biosynthesis  0.001231
# 3OAS121                            Fatty acid biosynthesis  0.001231
# 3OAS181                            Fatty acid biosynthesis  0.000535
# ADMDC                      Arginine and proline metabolism  0.000379
# NNDPR               Nicotinate and nicotinamide metabolism  0.000128
# DHNAPHT      Ubiquinone and other pterpenoids biosynthesis  0.000092
# OXGDC2       Ubiquinone and other pterpenoids biosynthesis  0.000092
# PPCDC                    Pantothenate and CoA biosynthesis  0.000032
# ASP1DC         Alanine, aspartate and glutamate metabolism  0.000032
# PPND     Phenylalanine tyrosine and tryptophan biosynth...  0.000029
# 34HPPOR  Phenylalanine tyrosine and tryptophan biosynth...  0.000029
# HGPHT        Ubiquinone and other pterpenoids biosynthesis  0.000029
# GLXCL              Glyoxylate and dicarboxylate metabolism  0.000025
# PC6YM                 Porphyrin and chlorophyll metabolism  0.000013
# THRPDC                Porphyrin and chlorophyll metabolism  0.000013
# OXGDC                            Citrate cycle (TCA cycle)  0.000006
#
#            percent   minimum    maximum  \
# GND      22.959038  0.000000  10.352270
# ICDHyr   11.866748  0.066532   4.458026
# ME2       8.063343  0.000000  15.508843
# ACLS      7.949891  0.044571   0.046917
# OMCDC     4.993888  0.027998   0.029472
# KAS15     3.953272  0.000000   0.023331
# 3OAS80    3.953272  0.022164   0.023331
# 3OAS100   3.953272  0.022164   0.023331
# 3OAS60    3.953272  0.022164   0.023331
# 3OAS120   3.744744  0.020995   0.022100
# 3OAS140   3.744744  0.020995   0.022100
# OMPDC     2.966541  0.016632   0.017507
# 3OAS160   2.784870  0.015614   0.016435
# ACHBS     2.747918  0.015406   0.016217
# DAPDC     1.832009  0.010271   0.010812
# PPNDH     1.757149  0.000000   0.010370
# DXPS      1.702777  0.009547   0.010049
# TYRA      1.277079  0.000000   0.007566
# 3OAS180   1.206270  0.006763   0.007119
# GLYCLa    1.034417 -0.027526   1.835971
# UPPDC1    0.831741  0.004663   0.004909
# IGPS      0.678176  0.003802   0.004002
# CPPPGO    0.415870  0.002332   0.002454
# UREA      0.380616  0.002134   9.543104
# ARGDC     0.380616  0.002134   0.002246
# 3OAS161   0.208528  0.001169   0.001231
# 3OAS141   0.208528  0.001169   0.001231
# 3OAS121   0.208528  0.001169   0.001231
# 3OAS181   0.090674  0.000508   0.000535
# ADMDC     0.064152  0.000360   0.000379
# NNDPR     0.021669  0.000121   0.000128
# DHNAPHT   0.015642  0.000088   0.000092
# OXGDC2    0.015642  0.000088   0.000092
# PPCDC     0.005479  0.000031   0.000031
# ASP1DC    0.005479  0.000031   0.000032
# PPND      0.004908  0.000000   0.007566
# 34HPPOR   0.004908  0.000028   0.000029
# HGPHT     0.004908  0.000028   0.000029
# GLXCL     0.004245  0.000000   1.886423
# PC6YM     0.002121  0.000012   0.000013
# THRPDC    0.002121  0.000012   0.000012
# OXGDC     0.000935  0.000000   4.391893
#
#                                                     string
# GND        6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c
# ICDHyr         icit_c + nadp_c --> akg_c + co2_c + nadph_c
# ME2          mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c
# ACLS                 h_c + 2.0 pyr_c --> alac__S_c + co2_c
# OMCDC                    3c4mop_c + h_c --> 4mop_c + co2_c
# KAS15    accoa_c + h_c + malACP_c --> actACP_c + co2_c ...
# 3OAS80   h_c + hexACP_c + malACP_c --> 3ooctACP_c + ACP...
# 3OAS100  h_c + malACP_c + ocACP_c --> 3odecACP_c + ACP_...
# 3OAS60   butACP_c + h_c + malACP_c --> 3ohexACP_c + ACP...
# 3OAS120  dcaACP_c + h_c + malACP_c --> 3oddecACP_c + AC...
# 3OAS140  ddcaACP_c + h_c + malACP_c --> 3omrsACP_c + AC...
# OMPDC                     h_c + orot5p_c --> co2_c + ump_c
# 3OAS160  h_c + malACP_c + myrsACP_c --> 3opalmACP_c + A...
# ACHBS           2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
# DAPDC                26dap__M_c + h_c --> co2_c + lys__L_c
# PPNDH             h_c + pphn_c --> co2_c + h2o_c + phpyr_c
# DXPS              g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c
# TYRA     Largn_c + nadp_c --> co2_c + h_c + nadph_c + t...
# 3OAS180  h_c + malACP_c + palmACP_c --> 3ooctdACP_c + A...
# GLYCLa               gly_c + lprot_c <=> co2_c + samprot_c
# UPPDC1          4.0 h_c + uppg3_c --> 4.0 co2_c + cpppg3_c
# IGPS            2cpr5p_c + h_c --> 3ig3p_c + co2_c + h2o_c
# CPPPGO   cpppg3_c + 2.0 h_c + o2_c --> 2.0 co2_c + 2.0 ...
# UREA        h2o_c + 2.0 h_c + urea_c --> co2_c + 2.0 nh4_c
# ARGDC                     arg__L_c + h_c --> agm_c + co2_c
# 3OAS161  h_c + malACP_c + tdeACP_c --> 3ocpalm9eACP_c +...
# 3OAS141  cddec5eACP_c + h_c + malACP_c --> 3ocmrs7eACP_...
# 3OAS121  cdec3eACP_c + h_c + malACP_c --> 3ocddec5eACP_...
# 3OAS181  h_c + hdeACP_c + malACP_c --> 3ocvac11eACP_c +...
# ADMDC                    amet_c + h_c --> ametam_c + co2_c
# NNDPR    2.0 h_c + prpp_c + quln_c --> co2_c + nicrnt_c...
# DHNAPHT  dhna_c + 2.0 fdxo_2_2_c + phdp_c --> co2_c + d...
# OXGDC2         akg_c + h_c + thmpp_c --> co2_c + ssaltpp_c
# PPCDC                   4ppcys_c + h_c --> co2_c + pan4p_c
# ASP1DC                  asp__L_c + h_c --> ala_B_c + co2_c
# PPND           nad_c + pphn_c --> 34hpp_c + co2_c + nadh_c
# 34HPPOR               34hpp_c + o2_c --> co2_c + hgentis_c
# HGPHT    h_c + hgentis_c + phdp_c --> 2m6phol_c + co2_c...
# GLXCL               2.0 glx_c + h_c --> 2h3oppan_c + co2_c
# PC6YM    2.0 amet_c + pre6b_c --> 2.0 ahcys_c + co2_c +...
# THRPDC                    h_c + thrp_c --> applp_c + co2_c
# OXGDC                     akg_c + h_c --> co2_c + sucsal_c

# %%
df_co2_consume.sort_values(by='percent', ascending=False)
# Out:
#                                      desciption            subsystem  \
# PPC             Phosphoenolpyruvate carboxylase  Pyruvate metabolism
# HCO3E               HCO3 equilibration reaction       Photosynthesis
# RBPC          Ribulose-bisphosphate carboxylase      Carbon fixation
# AIRCr  Phosphoribosylaminoimidazole carboxylase    Purine metabolism
#
#            flux    percent    minimum    maximum  \
# PPC   -0.206864  35.051918 -15.660125  -0.151313
# HCO3E -0.198081  33.563735  -6.057636  18.133445
# RBPC  -0.167028  28.301934 -11.631892   0.000000
# AIRCr -0.018191   3.082413  -0.018191  -0.017282
#
#                                                  string
# PPC        co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c
# HCO3E                    co2_c + h2o_c <=> h_c + hco3_c
# RBPC   co2_c + h2o_c + rb15bp_c --> 2.0 3pg_c + 2.0 h_c
# AIRCr                   air_c + co2_c <=> 5aizc_c + h_c

# %%
df_atp_produce_sort = df_atp_produce.sort_values(by='percent', ascending=False)
df_atp_consume_sort = df_atp_consume.sort_values(by='percent', ascending=False)
df_adp_produce_sort = df_adp_produce.sort_values(by='percent', ascending=False)
df_adp_consume_sort = df_adp_consume.sort_values(by='percent', ascending=False)
df_amp_produce_sort = df_amp_produce.sort_values(by='percent', ascending=False)
df_amp_consume_sort = df_amp_consume.sort_values(by='percent', ascending=False)
df_pi_produce_sort = df_pi_produce.sort_values(by='percent', ascending=False)
df_pi_consume_sort = df_pi_consume.sort_values(by='percent', ascending=False)
df_nadph_produce_sort = df_nadph_produce.sort_values(by='percent', ascending=False)
df_nadph_consume_sort = df_nadph_consume.sort_values(by='percent', ascending=False)
df_nadp_produce_sort = df_nadp_produce.sort_values(by='percent', ascending=False)
df_nadp_consume_sort = df_nadp_consume.sort_values(by='percent', ascending=False)
df_nadh_produce_sort = df_nadh_produce.sort_values(by='percent', ascending=False)
df_nadh_consume_sort = df_nadh_consume.sort_values(by='percent', ascending=False)
df_nad_produce_sort = df_nad_produce.sort_values(by='percent', ascending=False)
df_nad_consume_sort = df_nad_consume.sort_values(by='percent', ascending=False)
df_co2_produce_sort = df_co2_produce.sort_values(by='percent', ascending=False)
df_co2_consume_sort = df_co2_consume.sort_values(by='percent', ascending=False)
df_pyr_produce_sort = df_pyr_produce.sort_values(by='percent', ascending=False)
df_pyr_consume_sort = df_pyr_consume.sort_values(by='percent', ascending=False)

import pickle

with open('biomass_mixo_df_atp_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_atp_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_atp_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_atp_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_adp_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_adp_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_adp_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_adp_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_amp_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_amp_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_amp_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_amp_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)    
with open('biomass_mixo_df_pi_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_pi_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_pi_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_pi_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('biomass_mixo_df_nadph_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_nadph_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadph_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_nadph_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadp_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_nadp_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadp_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_nadp_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('biomass_mixo_df_nadh_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_nadh_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadh_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_nadh_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nad_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_nad_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nad_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_nad_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('biomass_mixo_df_co2_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_co2_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_co2_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_co2_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_pyr_produce_sort.pickle', 'wb') as handle:
    pickle.dump(df_pyr_produce_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_pyr_consume_sort.pickle', 'wb') as handle:
    pickle.dump(df_pyr_consume_sort, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle

with open('biomass_mixo_df_atp_produce.pickle', 'wb') as handle:
    pickle.dump(df_atp_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_atp_consume.pickle', 'wb') as handle:
    pickle.dump(df_atp_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_adp_produce.pickle', 'wb') as handle:
    pickle.dump(df_adp_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_adp_consume.pickle', 'wb') as handle:
    pickle.dump(df_adp_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_amp_produce.pickle', 'wb') as handle:
    pickle.dump(df_amp_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_amp_consume.pickle', 'wb') as handle:
    pickle.dump(df_amp_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_pi_produce.pickle', 'wb') as handle:
    pickle.dump(df_pi_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_pi_consume.pickle', 'wb') as handle:
    pickle.dump(df_pi_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('biomass_mixo_df_nadph_produce.pickle', 'wb') as handle:
    pickle.dump(df_nadph_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadph_consume.pickle', 'wb') as handle:
    pickle.dump(df_nadph_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadp_produce.pickle', 'wb') as handle:
    pickle.dump(df_nadp_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadp_consume.pickle', 'wb') as handle:
    pickle.dump(df_nadp_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('biomass_mixo_df_nadh_produce.pickle', 'wb') as handle:
    pickle.dump(df_nadh_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nadh_consume.pickle', 'wb') as handle:
    pickle.dump(df_nadh_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nad_produce.pickle', 'wb') as handle:
    pickle.dump(df_nad_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_nad_consume.pickle', 'wb') as handle:
    pickle.dump(df_nad_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('biomass_mixo_df_co2_produce.pickle', 'wb') as handle:
    pickle.dump(df_co2_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_co2_consume.pickle', 'wb') as handle:
    pickle.dump(df_co2_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_pyr_produce.pickle', 'wb') as handle:
    pickle.dump(df_pyr_produce, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('biomass_mixo_df_pyr_consume.pickle', 'wb') as handle:
    pickle.dump(df_pyr_consume, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Writing to an excel sheet
#
with pd.ExcelWriter('pfba_fva_biomass_mixo.xlsx') as writer:  
    df_atp_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='atp_produce')
    df_atp_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='atp_consume')
    df_adp_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='adp_produce')
    df_adp_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='adp_consume')
    df_amp_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='amp_produce')
    df_amp_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='amp_consume')
    df_pi_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='pi_produce')
    df_pi_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='pi_consume')
    df_nadph_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nadph_produce')
    df_nadph_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nadph_consume')
    df_nadp_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nadp_produce')
    df_nadp_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nadp_consume')
    df_nadh_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nadh_produce')
    df_nadh_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nadh_consume')
    df_nad_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nad_produce')
    df_nad_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='nad_consume')
    df_co2_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='co2_produce')
    df_co2_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='co2_consume')
    df_pyr_produce.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='pyr_produce')
    df_pyr_consume.sort_values(by='percent', ascending=False).to_excel(writer, sheet_name='pyr_consume')

# %% [markdown]
# ### Flux-sum analysis

# %%
atp_flux_sum = df_atp_produce['flux'].sum()
nadph_flux_sum = df_nadph_produce['flux'].sum()
nadh_flux_sum = df_nadh_produce['flux'].sum()
co2_flux_sum = df_co2_produce['flux'].sum()

ratio_atp_nadph = (atp_flux_sum / nadph_flux_sum)
ratio_nadph_nadh = (nadph_flux_sum / nadh_flux_sum)
ratio_atp_nadh = (atp_flux_sum / nadh_flux_sum)

# %%
# Generate dataframe summarizing the flux-sums of ATP/NADPH/NADH

df_flux_sum = {'ATP': [atp_flux_sum],
               'NADPH': [nadph_flux_sum],
               'NADH': [nadh_flux_sum],
               'ATP/NADPH': [ratio_atp_nadph],
               'NADPH/NADH': [ratio_nadph_nadh],
              'ATP/NADH': [ratio_atp_nadh]}

df_flux_sum = pd.DataFrame(data=df_flux_sum, index=['Biomass'])
df_flux_sum
# Out:
#               ATP     NADPH      NADH  ATP/NADPH  NADPH/NADH   ATP/NADH
# Biomass  10.69673  0.548712  0.135807  19.494245    4.040382  78.764193

# %%
df_flux_sum_co2 = {'CO2': [co2_flux_sum]}
df_flux_sum_co2 = pd.DataFrame(data=df_flux_sum_co2, index=['Biomass'])
df_flux_sum_co2
# Out:
#               CO2
# Biomass  0.590163

# %%
with open('biomass_mixo_df_flux_sum.pickle', 'wb') as handle:
    pickle.dump(df_flux_sum, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('biomass_mixo_df_flux_sum_co2.pickle', 'wb') as handle:
    pickle.dump(df_flux_sum_co2, handle, protocol=pickle.HIGHEST_PROTOCOL)
